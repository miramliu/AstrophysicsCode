# %%
import IPython.core.display as di
di.display_html('<script>jQuery(function() {if (jQuery("body.notebook_app").length == 0) { jQuery(".input_area").toggle(); jQuery(".prompt").toggle();}});</script>', raw=True)
# Out:
# <script>jQuery(function() {if (jQuery("body.notebook_app").length == 0) { jQuery(".input_area").toggle(); jQuery(".prompt").toggle();}});</script>

# %% [markdown]
# This is a plot of the ellipse (mirror in the FTS) that will be used in the ray tracer. The information regarding the legnths of the sides is gotten from the diagram in page 78 of the lab notebook.
#
# It is an ellipse with an origin located between the two foci. The line that the foci lie on is the axis of rotation that the ellipse is then rotated around.
#
# The units here are assumed to be centimeters.
#
# Mira

# %%
import numpy as np
import matplotlib
import matplotlib.pyplot as pl
import itertools
import math
from mpl_toolkits.mplot3d import Axes3D

# %% [markdown]
# The equation of an ellipse is given by $\frac{x^2}{a^2} + \frac{y^2}{b^2} = 1$
#
# In this ellipse (pre-rotation) b = 256, a = 263.9, c = 64.15
#
# A graph of this ellipse is shown below

# %%
pl3d = pl.figure().gca(projection = '3d')
origin = [0,0,0]
coeffellipse = [263.9,256,64.15] #a,b,c
xc=np.linspace(-coeffellipse[0],coeffellipse[0],100)
yc1 = np.sqrt((1-(xc**2)/(coeffellipse[0]**2))*coeffellipse[1])
yc2 = -np.sqrt((1-(xc**2)/(coeffellipse[0]**2))*coeffellipse[1])
zc = np.linspace(0,0,100)
pl.plot(xc,yc1,zc, 'blue')
#pl.plot(xc,yc2,zc, 'blue')
pl.show()

# %% [markdown]
# This ellipse is then rotated around the x-axis, which is also the axis in which the foci lie.

# %%
def Rx(x):
    Rx = np.matrix([[1,0,0],[0, np.cos(x), -np.sin(x)], [0, np.sin(x), np.cos(x)]])
    return Rx

# %%
Rotated = []
for i in range (0,100):
    v = [xc[i], yc1[i],zc[i]]
    v2 = np.array(np.dot(v,Rx(0 + i)))
    Rotated.append(v2[0])
xcR = []
ycR = []
zcR = []
for j in range (0,100):
    xcR.append(Rotated[j][0])
    ycR.append(Rotated[j][1])
    zcR.append(Rotated[j][2])

# %%
pl3d = pl.figure().gca(projection = '3d')
pl.plot(xcR,ycR,zcR, 'blue')
pl.title('rotating around axis')
pl.show()

# %% [markdown]
# Shown above is the general shape of the ellipse that is rotated about the x-axis. The mirrors are a tiny surface area of this ellipse. The rest of this will be getting this above graph as a surface.

# %%
Rotated = []
for i in range (0,100): 
    v = [xc[i], yc1[i],zc[i]] # number of original points
    v2 = np.array(np.dot(v,Rx(np.pi/2))) #multiplied by rotation vector
    Rotated.append(v2[0]) #rotated vectors
xcR1 = []
ycR1 = []
zcR1 = []
for j in range (0,100):
    xcR1.append(Rotated[j][0])
    ycR1.append(Rotated[j][1])
    zcR1.append(Rotated[j][2])

# %%
def createstrand(theta):
    Rotated = []
    for i in range (0,100): 
        v = [xc[i], yc1[i],zc[i]] # number of original points
        v2 = np.array(np.dot(v,Rx(theta))) #multiplied by rotation vector
        Rotated.append(v2[0]) #rotated vectors
    xcR1 = []
    ycR1 = []
    zcR1 = []
    for j in range (0,100):
        xcR1.append(Rotated[j][0])
        ycR1.append(Rotated[j][1])
        zcR1.append(Rotated[j][2])
    return xcR1,ycR1,zcR1

# %% [markdown]
# I want to be able to rotate the ellipse around the axis and connect all of the infinite number of lines that make up this rotating ellipse into a plane. The edges of this plane are shown below.

# %%
pl3d = pl.figure().gca(projection = '3d')
pl.plot(xc,yc1,zc, 'blue')
x,y,z = createstrand(np.pi/2)
pl.plot(x,y,z ,'green')
pl.show()

# %%
def createz(a,n):
    x1 = []
    y1 = []
    z1 = []
    for i in range (0,int(a)):
        theta = i*np.pi/n
        x,y,z = createstrand(theta)
        x1.extend(x)
        y1.extend(y)
        z1.extend(z)
    return x1,y1,z1

# %%
pl3dsurf = pl.figure().gca(projection = '3d')
X,Y,Z = createz(20,40)
X.pop(0)
Y.pop(0)
Z.pop(0)
pl3dsurf.plot_trisurf(X,Y,Z, linewidth = .2)
#pl3dsurf.set_zlim(-4,0)
pl.show()

# %% [markdown]
# This is gotten from creating sets of fectors that make up each rotated vector and triangulating to create the surface that would lie between them. It is clear there is a problem due to the dominance of one huge triangle made from the tip points.
#
# The same plot with varying angles is shown below.

# %%
pl3dsurf = pl.figure().gca(projection = '3d')
X,Y,Z = createz(10,10)
X.pop(0)
Y.pop(0)
Z.pop(0)
pl3dsurf.plot_trisurf(X,Y,Z, linewidth = .2)
#pl3dsurf.set_zlim(-4,0)
pl.show()

# %%
pl3dsurf = pl.figure().gca(projection = '3d')
X,Y,Z = createz(30,70)
X.pop(0)
Y.pop(0)
Z.pop(0)
pl3dsurf.plot_trisurf(X,Y,Z, linewidth = .2)
#pl3dsurf.set_zlim(-4,0)
pl.show()

# %%
pl3dsurf = pl.figure().gca(projection = '3d')
X,Y,Z = createz(30,190)
X.pop(0)
Y.pop(0)
Z.pop(0)
pl3dsurf.plot_trisurf(X,Y,Z, linewidth = .2)
#pl3dsurf.set_zlim(-4,0)
pl.show()

# %%
pl3dsurf = pl.figure().gca(projection = '3d')
X,Y,Z = createz(30,15)
X.pop(0)
Y.pop(0)
Z.pop(0)
pl3dsurf.plot_trisurf(X,Y,Z, linewidth = .2, antialiased=True)
#pl3dsurf.set_zlim(-4,0)
pl.show()

# %% [markdown]
# The last plot, which is supposed to be a completion of the entire ellpisoid, shows I am not understanding something fundamental.

# %%
def createz2(a,n):
    x1 = []
    y1 = []
    z1 = []
    for i in range (0,a):
        theta = np.linspace(0,n,a)
        x,y,z = createstrand(theta[i])
        x1.extend(x)
        y1.extend(y)
        z1.extend(z)
    return x1,y1,z1,

# %%
pl3dsurf = pl.figure().gca(projection = '3d')
X,Y,Z = createz2(10,np.pi/2)
X.pop(0)
Y.pop(0)
Z.pop(0)
pl3dsurf.plot_trisurf(X,Y,Z, linewidth = .2, antialiased=True)
#pl3dsurf.set_zlim(-4,0)
pl.show()

# %% [markdown]
# An edit got rid of this triangle!  It should work now.

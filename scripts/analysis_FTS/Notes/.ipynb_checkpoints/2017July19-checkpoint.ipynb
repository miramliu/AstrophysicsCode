# %%
import IPython.core.display as di
di.display_html('<script>jQuery(function() {if (jQuery("body.notebook_app").length == 0) { jQuery(".input_area").toggle(); jQuery(".prompt").toggle();}});</script>', raw=True)
# Out:
# <script>jQuery(function() {if (jQuery("body.notebook_app").length == 0) { jQuery(".input_area").toggle(); jQuery(".prompt").toggle();}});</script>

# %% [markdown]
# This is a summary of the work done from the second half of the 18th to the 19th. This involved writing and running the functions that coorectly reflect a ray off of an ellipse from the inside using the normal and gradient of the tangent plane at the intersection point.
#
# The entire ellipsoid is then restricted to within a certain x range to match the FTS design.
#
# The notebooks in this are FTSCenterEllipse and MultipleFTSEllipses. (See pages 86-89)
#
# Mira

# %%
import numpy as np
import matplotlib.pyplot as pl
import itertools
from mpl_toolkits.mplot3d import Axes3D
from raytracefunnotes import *

# %%
pli = [0,0,0] #(x0,y0,z0)
v1 = [1,1,1] #a,b,c
coeffellipse = [263.9,256,64.15]
c = tangcoef(pli,v1,coeffellipse)
r = int(100)
v = [1,1,1]
p = [0,0,0]
L = int(300)
xi,yi,zi,xr,yr,zr,xp,yp,zp = reflectneg(c,r,v,p,L)
xint,yint,zint = ellipselineint(p,v,coeffellipse)

# %%
#tangent plane
pl3dsurf = pl.figure().gca(projection = '3d')
X,Y,Z = createz(50,np.pi*1.99, [263.9,256,64.15])
X.pop(0)
Y.pop(0)
Z.pop(0)
pl3dsurf.plot_trisurf(X,Y,Z, linewidth = .2, antialiased=True)
pli = [0,0,0] #(x0,y0,z0)
vl = [1,1,1] #a,b,c
coeffellipse = [263.9,256,64.15]
xint,yint,zint = ellipselineint(pli,v1,coeffellipse)
xp,yp,zp= tangplane(pli,v1,coeffellipse,300)
pl3dsurf.plot_surface(xp,yp,zp, alpha = .2)
L1 = int(300)
xline,yline,zline = make_line(pli,vl,L1)
pl.plot(xline,yline,zline, color = 'yellow')
pl3dsurf.plot([xint[0]],[yint[0]],[zint[0]], marker = 'o', color = 'white')
pl.show()
#YAY IT WORKS

# %% [markdown]
# This shows the sphere with the tangent plane at the specific intersection point of the ray (yellow) and the ellipsoid.

# %%
pl3d = pl.figure().gca(projection = '3d')
xp1,yp1,zp1= tangplane(p,v,coeffellipse,300)
pl3d.plot_surface(xp1,yp1,zp1, alpha = .2)
#pl.plot(xline,yline,zline, color = 'yellow')
pl3d.plot([xint[0]],[yint[0]],[zint[0]], marker = 'o', color = 'white')

pl.plot(xi,yi,zi, 'blue') 
pl.plot(xr,yr,zr, 'red')
pl.show()

# %% [markdown]
# This shows the initial ray (blue) hitting the ellipsoid (invisible) at the intersection point (white). The reflecting ray (red) is shown as reflecting from that point off of the tangent plane.

# %%
pl3dsurf = pl.figure().gca(projection = '3d')
coeffellipse = [263.9,256,64.15]
X,Y,Z = createzbounded(50,np.pi/4, coeffellipse, 64.15)
X.pop(0)
Y.pop(0)
Z.pop(0)
pl3dsurf.plot_trisurf(X,Y,Z, linewidth = .2, antialiased=True)
pli = [0,200,-100] #(x0,y0,z0)
v1 = [0.01,1,.01] #(a,b,c)
L1 = int(200)
xline,yline,zline = make_line(pli,v1,L1)
pl3dsurf.plot(xline,yline,zline, color = 'yellow')
xint,yint,zint = ellipselineint(pli,v1,coeffellipse)
pl3dsurf.plot([xint[0]],[yint[0]],[zint[0]], marker = 'o', color = 'white')
pl.show()

# %% [markdown]
# This is a segment of the ellipse. A ray (yellow) is shown that 'goes through' the ellipse, with the intersection point marked as white. This was merely to make sure intersection is accurate.
#
# Note: Tangent planes will not be physically shown from now on. I attempted to make it easier by using a tangent plane that isn't centered at zero, but python refused to cooperate. Therefore this simple visualization will be skipped and used merely mathematically. (an example of the difficulty is shown below)

# %%
pl3dsurf = pl.figure().gca(projection = '3d')
pl3dsurf.plot_trisurf(X,Y,Z, linewidth = .2, antialiased=True)
pl3dsurf.plot(xline,yline,zline, color = 'yellow')
pl3dsurf.plot([xint[0]],[yint[0]],[zint[0]], marker = 'o', color = 'white')
xp,yp,zp= tangplane(pli,v1,coeffellipse,100)
pl3dsurf.plot_surface(xp,yp,zp, alpha = .2)
pl.show()

# %%
c = tangcoef(pli,v1,coeffellipse)
r = int(100)
p = [0,200,-100] #(x0,y0,z0)
v = [0.01,1,.01] #(a,b,c)
L = int(200)
coeffellipse = [263.9,256,64.15]
xi,yi,zi,xr,yr,zr,xp,yp,zp  = reflectellipse(coeffellipse,r,v,p,L)
xint,yint,zint = ellipselineint(p,v,coeffellipse)

pl3dsurf = pl.figure().gca(projection = '3d')
pl3dsurf.plot([xint[0]],[yint[0]],[zint[0]], marker = 'o', color = 'white')
#pl3dsurf.plot(xline,yline,zline, color = 'yellow')
pl3dsurf.plot(xi,yi,zi, color = 'yellow')
pl3dsurf.plot(xr,yr,zr, color = 'red')
pl3dsurf.plot_trisurf(X,Y,Z, linewidth = .2, antialiased=True)
#pl3dsurf.plot_surface(xp,yp,zp, alpha = .2)
pl.show()

# %% [markdown]
# THIS is the initial ray hitting at a point and reflecting off of the ellipsoid at the point of intersection!!!

# %%
#will now try with a source! 
pl3d = pl.figure().gca(projection = '3d')
#try to show source reflected off of one flat surface (ASSUMING THIS IS CORRECT?)
axis = [0,200,8] #hkr
x,y,z=shape_source(axis,-100)
#pl3d.plot_surface(xp,yp,zp, alpha = .2)

points = list_points(x,y,z)
xi,yi,zi,xr,yr,zr,xp,yp,zp = reflect_sourceellipse(coeffellipse,r,v,points,L)
for n in range (0,len(list_points(x,y,z))):
    pl3d.plot(xi[n],yi[n],zi[n])
    pl3d.plot(xr[n],yr[n],zr[n])
pl3d.plot_trisurf(X,Y,Z, linewidth = .2, antialiased=True)
ax=pl.gca()
ax.hold(True)
pl.show()

# %% [markdown]
# The figure above shows the reflection of a source off of the ellipse. The source has the dimensions as a circle centered at x = 0, y = 200, at z = -100.

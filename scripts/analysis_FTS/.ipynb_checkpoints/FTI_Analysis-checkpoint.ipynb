# %%
import pickle
import glob
import matplotlib.pyplot as pl
import numpy as np
import os
    
default_directory = '../software/' 
stri = raw_input('file pathway: ')
if len(stri)>1:
    default_directory = stri
default_extension = '*.pkl'
    
q=os.path.join(default_directory, default_extension)
print q
    
for name in glob.glob(q): 
    print name
    

f = raw_input ('Pickle File Name: ')
g = os.path.join(stri, f)

X = str(g)
    
print X
    
file=open( X , 'rb')
d=pickle.load(file)
file.close()


g = raw_input('Signal(0F or 0R): ')
Y = str(g)
    
pl.ion()

fig = pl.figure(1)
ax2 = pl.subplot2grid((2,1), (0,0), colspan=1,)
ax2.plot (d['delay'+ Y], d['sig'+Y])
ax2.set_xlabel ("Delay0F")
ax2.set_ylabel ("Sig0F")


i = 8
Nsize = 2**i
dt=(1/(d['sample freq']))
t=dt*np.arange(Nsize)
v=(d['speed'])
x = v*t
dx = dt*v
total_t = (d['scan time'])
    
total_s = (d['samples requested'])
startpt = ((total_s - Nsize)/2) 
endpt = startpt + Nsize
    
F = (d['sig'+Y])
A = F[startpt:endpt]
S = np.fft.rfft(A)
    
S = S[:-1]
u = np.abs(S)
dNu = 1/(Nsize*dx)
Nu = dNu*np.arange(Nsize/2)


ax1 = pl.subplot2grid((2,1), (1,0),colspan =1)
ax1.plot (300*Nu,np.abs(S)) 
ax1.set_xlabel ("frequency, GHz")
ax1.set_ylabel ('Arb')
# Out:
# file pathway: ../../data/raw_data/
# ../../data/raw_data/*.pkl
# ../../data/raw_data/10mmpersec70mm.pkl
# ../../data/raw_data/10mmpersec70mm_2.pkl
# ../../data/raw_data/20160119_1021_Reference_1.pkl
# ../../data/raw_data/20160119_1023_Reference_1.pkl
# ../../data/raw_data/20160119_1109_2_Hz_function_generator.pkl
# ../../data/raw_data/20160119_1114_2_Hz_square.pkl
# ../../data/raw_data/20160119_1149_2_Hz_square_new_vel.pkl
# ../../data/raw_data/20160211_1405_2_Hz_square_new_vel.pkl
# ../../data/raw_data/20160218_1231_test.pkl
# ../../data/raw_data/20160218_1307_inputTransBlocked.pkl
# ../../data/raw_data/20160218_1311_inputTransBlocked2.pkl
# ../../data/raw_data/20160218_1320_inputReflBlocked.pkl
# ../../data/raw_data/20160218_1325_inputReflBlocked2.pkl
# ../../data/raw_data/20160218_1327_inputReflBlocked3.pkl
# ../../data/raw_data/20160218_1337_NominalRitoMods.pkl
# ../../data/raw_data/20160218_1341_NominalRitoMods2.pkl
# ../../data/raw_data/20160218_1350_RitoModsInTransBlocked.pkl
# ../../data/raw_data/20160218_1412_RitoModsInTra.pkl
# ../../data/raw_data/20160218_1459_RitoMods1_LargeAperture_test0.pkl
# ../../data/raw_data/20160218_1503_RitoMods1_SmallAperture_test1.pkl
# ../../data/raw_data/20160218_1505_RitoMods1_LargeAperture_test2.pkl
# ../../data/raw_data/20160218_1508_RitoMods1_SmallAperture_test3.pkl
# ../../data/raw_data/20160218_1515_1Blocked_SmallAperture_test1.pkl
# ../../data/raw_data/20160218_1517_1Blocked_(too slow)_test3.pkl
# ../../data/raw_data/20160218_1529_1Blocked_SmallAperture_test3.pkl
# ../../data/raw_data/20160218_
# ../../data/raw_data/ap050.pkl
# ../../data/raw_data/apo25_2.pkl
# ../../data/raw_data/apo25_3.pkl
# ../../data/raw_data/apo25_with_baffle.pkl
# ../../data/raw_data/DHW90_10mmpersec70mm.pkl
# ../../data/raw_data/no_absorber_on_septum.pkl
# ../../data/raw_data/no_absorber_on_septum_chopped.pkl
# ../../data/raw_data/no_absorber_on_septum_chopped_p2aperture.pkl
# ../../data/raw_data/no_absorber_on_septum_p1aperture.pkl
# ../../data/raw_data/no_absorber_on_septum_p2aperture.pkl
# ../../data/raw_data/no_absorber_on_septum_p2apertureandfoam.pkl
# ../../data/raw_data/no_absorber_on_septum_p2apertureandfoam2.pkl
# ../../data/raw_data/no_absorber_on_septum_p2apertureandfoam_chopped.pkl
# ../../data/raw_data/no_absorber_on_septum_p6apertureandfoam2.pkl
# ../../data/raw_data/no_absorber_on_septum_p6apertureandfoam_chopped.pkl
# ../../data/raw_data/right_sideup.pkl
# ../../data/raw_data/Second_set_of_absorbers.pkl
# ../../data/raw_data/Second_set_of_absorbers_2.pkl
# ../../data/raw_data/third_set_of_absorbers.pkl
# ../../data/raw_data/third_set_of_absorbers_2.pkl
# Pickle File Name: 20160428_1526_T0001_ref.pkl
# ../../data/raw_data/20160428_1526_T0001_ref.pkl
# Signal(0F or 0R): 0F
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-2-2ac1e515310f> in <module>()
#      66
#      67 ax1 = pl.subplot2grid((2,1), (1,0),colspan =1)
# ---> 68 ax1.plot (300*Nu,np.abs(S))
#      69 ax1.set_xlabel ("frequency, GHz")
#      70 ax1.set_ylabel ('Arb')
#
# /Users/Lab/anaconda2/lib/python2.7/site-packages/matplotlib/__init__.pyc in inner(ax, *args, **kwargs)
#    1810                     warnings.warn(msg % (label_namer, func.__name__),
#    1811                                   RuntimeWarning, stacklevel=2)
# -> 1812             return func(ax, *args, **kwargs)
#    1813         pre_doc = inner.__doc__
#    1814         if pre_doc is None:
#
# /Users/Lab/anaconda2/lib/python2.7/site-packages/matplotlib/axes/_axes.pyc in plot(self, *args, **kwargs)
#    1422             kwargs['color'] = c
#    1423
# -> 1424         for line in self._get_lines(*args, **kwargs):
#    1425             self.add_line(line)
#    1426             lines.append(line)
#
# /Users/Lab/anaconda2/lib/python2.7/site-packages/matplotlib/axes/_base.pyc in _grab_next_args(self, *args, **kwargs)
#     384                 return
#     385             if len(remaining) <= 3:
# --> 386                 for seg in self._plot_args(remaining, kwargs):
#     387                     yield seg
#     388                 return
#
# /Users/Lab/anaconda2/lib/python2.7/site-packages/matplotlib/axes/_base.pyc in _plot_args(self, tup, kwargs)
#     362             x, y = index_of(tup[-1])
#     363
# --> 364         x, y = self._xy_from_xy(x, y)
#     365
#     366         if self.command == 'plot':
#
# /Users/Lab/anaconda2/lib/python2.7/site-packages/matplotlib/axes/_base.pyc in _xy_from_xy(self, x, y)
#     221         y = _check_1d(y)
#     222         if x.shape[0] != y.shape[0]:
# --> 223             raise ValueError("x and y must have same first dimension")
#     224         if x.ndim > 2 or y.ndim > 2:
#     225             raise ValueError("x and y can be no greater than 2-D")
#
# ValueError: x and y must have same first dimension

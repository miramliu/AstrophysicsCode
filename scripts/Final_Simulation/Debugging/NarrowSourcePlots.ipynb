# %%
import numpy as np
import matplotlib.pyplot as pl
import itertools
from mpl_toolkits.mplot3d import Axes3D
from RayTraceFunctions import * 
from random import uniform
import random
import pickle
import math
import time

# %%
with open( 'Delay_Chamb_144_Vert_500_2.07mm_2019_06_07_18_04_55.pkl' , 'rb') as file1:
    D=pickle.load(file1, encoding = 'latin1')
with open( 'Ij_Chamb_144_Vert_500_2.07mm_2019_06_07_18_04_55.pkl' , 'rb') as file1:
    ij=pickle.load(file1, encoding = 'latin1')
    
pl.plot(D,ij)
pl.show()  

print('vertical no solid angle')
# Out:
# vertical no solid angle

# %%
with open( 'Delay_Chamb_144_Narrow_10_2.07mm_2019_05_30_14_37_38.pkl' , 'rb') as file1:
    D=pickle.load(file1, encoding = 'latin1')
with open( 'Ij_Chamb_144_Narrow_10_2.07mm_2019_05_30_14_37_38.pkl' , 'rb') as file1:
    ij=pickle.load(file1, encoding = 'latin1')
    
pl.plot(D,ij)
pl.show()  

print('10 degree solid angle')
# Out:
# 10 degree solid angle

# %%
with open( 'Delay_Chamb_144_Narrow_20_2.07mm_2019_05_29_15_28_27.pkl' , 'rb') as file1:
    D=pickle.load(file1, encoding = 'latin1')
with open( 'Ij_Chamb_144_Narrow_20_2.07mm_2019_05_29_15_28_27.pkl' , 'rb') as file1:
    ij=pickle.load(file1, encoding = 'latin1')
    
pl.plot(D,ij)
pl.show()  

print('20 degree solid angle')
# Out:
# 20 degree solid angle

# %% [markdown]
# with open( 'Delay_Chamb_144_Narrow_30_2.07mm_2019_05_27_12_01_57.pkl' , 'rb') as file1:
#     D=pickle.load(file1, encoding = 'latin1')
# with open( 'Ij_Chamb_144_Narrow_30_2.07mm_2019_05_27_12_01_57.pkl' , 'rb') as file1:
#     ij=pickle.load(file1, encoding = 'latin1')
#
# pl.plot(D,ij)
# pl.show()
#
# print('30 degree solid angle')

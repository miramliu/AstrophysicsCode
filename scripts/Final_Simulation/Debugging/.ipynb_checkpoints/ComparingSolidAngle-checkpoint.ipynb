# %% [markdown]
# Comparing the effect of solid angle (10,20,30,none) on the chamberlain loss. Are expecting LESS loss with SMALLER solid angle.

# %%
import numpy as np
import matplotlib.pyplot as pl
import itertools
from mpl_toolkits.mplot3d import Axes3D
from RayTraceFunctions import * 
from random import uniform
import random
import pickle
import math
import time

# %%
with open( 'Delay_Chamb_144_Narrow_30_2.07mm_2019_05_27_12_01_57.pkl' , 'rb') as file1:
    Delay_30=pickle.load(file1, encoding = 'latin1') 
with open( 'Delay_Chamb_144_Narrow_20_2.07mm_2019_05_29_15_28_27.pkl' , 'rb') as file1:
    Delay_20=pickle.load(file1, encoding = 'latin1')
with open( 'Delay_Chamb_144_Narrow_10_2.07mm_2019_05_30_14_37_38.pkl' , 'rb') as file1:
    Delay_10=pickle.load(file1, encoding = 'latin1')
    
with open( 'Ij_Chamb_144_Narrow_30_2.07mm_2019_05_27_12_01_57.pkl' , 'rb') as file1:
    Ij_30=pickle.load(file1, encoding = 'latin1')
with open( 'Ij_Chamb_144_Narrow_20_2.07mm_2019_05_29_15_28_27.pkl' , 'rb') as file1:
    Ij_20=pickle.load(file1, encoding = 'latin1') 
with open( 'Ij_Chamb_144_Narrow_10_2.07mm_2019_05_30_14_37_38.pkl' , 'rb') as file1:
    Ij_10=pickle.load(file1, encoding = 'latin1')

# %%
Lamd =2.089
Nsize = Nsized(Lamd)
Freq = float(300/Lamd)

d1 = Ij_10
D = np.hanning(int(np.shape(d1)[0]))*d1
S = np.fft.rfft(D)
#S = S[1:]
u = np.abs(S)
xtot = 36*0.95630475596*4 #total length of the scan
df = 1/xtot
f = df*np.arange(1+Nsize/2)-df/2

pl.plot(Delay_10,Ij_10/max(Ij_10),linewidth = .8) 
pl.tick_params(colors = 'black')
#pl.title('$\lambda$='+str(Lamd),color = 'black')
pl.xlabel('Optical Delay (mm)', color = 'black')
#pl.savefig('1CenterRayInt.png',dpi=1000)
pl.show() 

pl.plot(300*f[3:],u[3:])
#pl.title('FFT of above',color = 'black')
pl.xlabel('GHz', color = 'black')
pl.tick_params(colors = 'black')
pl.axvline(x =float(Freq), color = 'green', label = str(Freq)+'GHz')
pl.xlim(0,200)
pl.legend()
#pl.savefig('1CenterRaySpec.png',dpi=1000)
pl.show()
#with one ray

# %%
Lamd =2.089
Nsize = Nsized(Lamd)
Freq = float(300/Lamd)

d1 = Ij_20
D = np.hanning(int(np.shape(d1)[0]))*d1
S = np.fft.rfft(D)
#S = S[1:]
u = np.abs(S)
xtot = 36*0.95630475596*4 #total length of the scan
df = 1/xtot
f = df*np.arange(1+Nsize/2)-df/2

pl.plot(Delay_20,Ij_20/max(Ij_20),linewidth = .8) 
pl.tick_params(colors = 'black')
#pl.title('$\lambda$='+str(Lamd),color = 'black')
pl.xlabel('Optical Delay (mm)', color = 'black')
#pl.savefig('1CenterRayInt.png',dpi=1000)
pl.show() 

pl.plot(300*f[3:],u[3:])
#pl.title('FFT of above',color = 'black')
pl.xlabel('GHz', color = 'black')
pl.tick_params(colors = 'black')
pl.axvline(x =float(Freq), color = 'green', label = str(Freq)+'GHz')
pl.xlim(0,200)
pl.legend()
#pl.savefig('1CenterRaySpec.png',dpi=1000)
pl.show()
#with one ray

# %%
Lamd =2.089
Nsize = Nsized(Lamd)
Freq = float(300/Lamd)

d1 = Ij_30
D = np.hanning(int(np.shape(d1)[0]))*d1
S = np.fft.rfft(D)
#S = S[1:]
u = np.abs(S)
xtot = 36*0.95630475596*4 #total length of the scan
df = 1/xtot
f = df*np.arange(1+Nsize/2)-df/2

pl.plot(Delay_30,Ij_30/max(Ij_30),linewidth = .8) 
pl.tick_params(colors = 'black')
#pl.title('$\lambda$='+str(Lamd),color = 'black')
pl.xlabel('Optical Delay (mm)', color = 'black')
#pl.savefig('1CenterRayInt.png',dpi=1000)
pl.show() 

pl.plot(300*f[3:],u[3:])
#pl.title('FFT of above',color = 'black')
pl.xlabel('GHz', color = 'black')
pl.tick_params(colors = 'black')
pl.axvline(x =float(Freq), color = 'green', label = str(Freq)+'GHz')
pl.xlim(0,200)
pl.legend()
#pl.savefig('1CenterRaySpec.png',dpi=1000)
pl.show()
#with one ray

# %% [markdown]
# # Am now running simulation with no solid angle (all vertical) and original simulation (no limit to angle)

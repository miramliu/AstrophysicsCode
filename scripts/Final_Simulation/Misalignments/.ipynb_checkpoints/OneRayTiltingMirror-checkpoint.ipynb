# %% [markdown]
# two main types of misalignment: Source & Septum
# Source:
#     - tilting of source
#     - movement of source in focal plane
# Septum:
#     - tilting of mirrors/polarizers within the septum
#     - incorrect tilting of polarizers (so incorrect polarization)

# %%
import numpy as np
import matplotlib.pyplot as pl
import itertools
from mpl_toolkits.mplot3d import Axes3D
from RayTraceFunctionsTilting import * 
from random import uniform
import random
import pickle
import math
import time

# %%
#now messing around with Nsize??? like trying to UNDERSAMPLE
Timei = time.time()
print('Running')
Lamd = 1.01
Nsize = Nsized(Lamd)
spo = [-160.375,-113.,-80.0] #global CENTERED
thetmirr = [0.0,0.0, -np.pi/200] 
v = [0.,0.,1.]
Delay,Ij = RunOneRayTiltSource(Lamd,Nsize,spo,thetmirr)
Timef = time.time()
print('total time: ~',float(Timef-Timei)/60, 'mins')
pl.plot(Delay,Ij,linewidth = .8) 
pl.tick_params(colors = 'black')
pl.title('$\lambda$='+str(Lamd),color = 'black')
pl.xlabel('Optical Delay (mm)', color = 'black')
pl.show()

# %%
Timei = time.time()
print('Running')
Lamd = 3.32
Nsize = Nsized(Lamd)
#Nsize = 8192
Freq = float(300/Lamd)
spo = [-160.375,-113.,-80.0] #global CENTERED
thetmirr = [0.0,0.0, np.pi/100] 
v = [0.,0.,1.]
Delay,Ij = RunOneRayTiltSource(Lamd,Nsize,spo,thetmirr)
with open("Imirrortilt_" + str(thetmirr[2]) +'lambda_'+str(Lamd)+'mm'+time.strftime("_%Y_%m_%d_%H_%M_%S") + ".pkl", "wb") as f:
    pickle.dump(Ij,f)
with open("Dmirrortilt_" + str(thetmirr[2]) +'lambda_'+str(Lamd)+'mm'+time.strftime("_%Y_%m_%d_%H_%M_%S") + ".pkl", "wb") as f:
    pickle.dump(Delay,f)
Timef = time.time()
print('total time: ~',float(Timef-Timei)/60, 'mins')
pl.plot(Delay,Ij,linewidth = .8) 
pl.tick_params(colors = 'black')
pl.title('$\lambda$='+str(Lamd),color = 'black')
pl.xlabel('Optical Delay (mm)', color = 'black')
pl.show()

# %%
with open( 'Dmirrortilt_0.031415926535897934lambda_3.32mm_2018_06_26_19_44_31.pkl' , 'rb') as file1:
    D1=pickle.load(file1, encoding = 'latin1')
with open('Imirrortilt_0.031415926535897934lambda_3.32mm_2018_06_26_19_44_31.pkl','rb') as file2:
    I1 = pickle.load(file2, encoding = 'latin1')
I1=np.array(I1)
a = max(I1)
b = max(I1)/2
I = [(x-b)/(a/2) for x in I1]   
pl.plot(D1,I)
pl.title('Mirror Tilt',color = 'black')
pl.xlabel('Optical Delay (mm)', color = 'black')
pl.savefig('MirrTilt.png')
pl.show()

# %%
Timei = time.time()
print('Running')
Lamd = 3.32
Nsize = Nsized(Lamd)
#Nsize = 8192
Freq = float(300/Lamd)
spo = [-160.375,-113.,-80.0] #global CENTERED
#spo1 = [-152.4375, -113.0,-80.]
#XY = [spo1[0],spo1[1]]
#print(XY)
#p1 = np.pi/4.2 #off by 0.03739991254
#p2 = np.pi/2.2
#p3 = np.pi/1.2
#p4 = np.pi/3.8
thetmirr = [np.pi/100,0.0,0.0] 
v = [0.,0.,1.]
Delay,Ij = RunOneRayTiltSource(Lamd,Nsize,spo,thetmirr)
#with open("Plots/OneRayI"+str(XY)+str(Lamd)+'mm'+time.strftime("_%Y_%m_%d_%H_%M_%S") + ".pkl", "wb") as f:
    #pickle.dump(Ij,f)
#with open("Plots/OneRayD"+str(XY)+str(Lamd)+'mm'+time.strftime("_%Y_%m_%d_%H_%M_%S") + ".pkl", "wb") as f:
    #pickle.dump(Delay,f)
Timef = time.time()
print('total time: ~',float(Timef-Timei)/60, 'mins')
pl.plot(Delay,Ij,linewidth = .8) 
pl.tick_params(colors = 'black')
pl.title('$\lambda$='+str(Lamd),color = 'black')
pl.xlabel('Optical Delay (mm)', color = 'black')
pl.show()

# %%
Timei = time.time()
print('Running')
Lamd = 3.32
Nsize = Nsized(Lamd)
#Nsize = 8192
Freq = float(300/Lamd)
spo = [-160.375,-113.,-80.0] #global CENTERED
#spo1 = [-152.4375, -113.0,-80.]
#XY = [spo1[0],spo1[1]]
#print(XY)
#p1 = np.pi/4.2 #off by 0.03739991254
#p2 = np.pi/2.2
#p3 = np.pi/1.2
#p4 = np.pi/3.8
thetmirr = [np.pi/100,0.0,0.0] 
v = [0.,0.,1.]
Delay,Ij = RunOneRayTiltSource(Lamd,Nsize,spo,thetmirr)
#with open("Plots/OneRayI"+str(XY)+str(Lamd)+'mm'+time.strftime("_%Y_%m_%d_%H_%M_%S") + ".pkl", "wb") as f:
    #pickle.dump(Ij,f)
#with open("Plots/OneRayD"+str(XY)+str(Lamd)+'mm'+time.strftime("_%Y_%m_%d_%H_%M_%S") + ".pkl", "wb") as f:
    #pickle.dump(Delay,f)
Timef = time.time()
print('total time: ~',float(Timef-Timei)/60, 'mins')
pl.plot(Delay,Ij/max(Ij),linewidth = .8) 
pl.tick_params(colors = 'black')
pl.title('Mirror Tilt',color = 'black')
pl.xlabel('Optical Delay (mm)', color = 'black')
pl.savefig('MirrorTilting_Pure')
         
pl.show()
# Out:
# Running
# total time: ~ 0.8666165510813395 mins

# %% [markdown]
# thetmirr = [0.,0.,0.]
# originM = [0.,0.,0.]
# r = 0
# n = 1
# spo = [-160.375,-113.,-80.0] #global CENTERED
#
# Rays = makeraysVERTICAL(spo,r,n)
# TTTTioMtilt(Rays[0],p1,p2,p3,p4,originM,thetmirr)

# %% [markdown]
# Ray1 = ReflEll(Rays[0],thet10,origin10,coeffellipse7,center10,range10)

# %% [markdown]
# Ray2 = OFDMtilt(Rays,y,thetmirr)

# %% [markdown]
# Rays= makeraysVERTICAL(spo,0,1)
# Rays[0]
# thetmirr = [0.,0.,0.]
# for y in np.linspace(-18,18,2):
#     originmirr = [0.,y,0.]
#     if RunRaysMtilt(Rays,y,thetmirr) != RunRaysM(Rays,y):
#         print('err')
#     #print('new: ', IntM2tilt(R1,thetmirr,coeffmirr,originmirr))
#     #print('old: ', IntM2(R1,coeffmirr,originmirr))

# %% [markdown]
# Timei = time.time()
# Lamd = 3.32
# Nsize = Nsized(Lamd)
# #Nsize = 8192
# Freq = float(300/Lamd)
# spo = [-160.375,-113.,-80.0] #global CENTERED
# spo1 = [-152.4375, -113.0,-80.]
# #XY = [spo1[0],spo1[1]]
# #print(XY)
#
# Delay,Ij = RunOneRay(Lamd,Nsize,spo)
# #with open("Plots/OneRayI"+str(XY)+str(Lamd)+'mm'+time.strftime("_%Y_%m_%d_%H_%M_%S") + ".pkl", "wb") as f:
#     #pickle.dump(Ij,f)
# #with open("Plots/OneRayD"+str(XY)+str(Lamd)+'mm'+time.strftime("_%Y_%m_%d_%H_%M_%S") + ".pkl", "wb") as f:
#     #pickle.dump(Delay,f)
# Timef = time.time()
# print('total time: ~',float(Timef-Timei)/60, 'mins')
# pl.plot(Delay,Ij,linewidth = .8)
# pl.tick_params(colors = 'black')
# pl.title('$\lambda$='+str(Lamd),color = 'black')
# pl.xlabel('Optical Delay (mm)', color = 'black')
# pl.show()

# %%
Timei = time.time()
print('Running')
Lamd = 3.32
Nsize = Nsized(Lamd)
#Nsize = 8192
Freq = float(300/Lamd)
spo = [-160.375,-113.,-80.0] #global CENTERED
#spo1 = [-152.4375, -113.0,-80.]
#XY = [spo1[0],spo1[1]]
#print(XY)
#p1 = np.pi/4.2 #off by 0.03739991254
#p2 = np.pi/2.2
#p3 = np.pi/1.2
#p4 = np.pi/3.8
thetmirr = [0.0,np.pi/100, -np.pi/100] 
v = [0.,0.,1.]
Delay,Ij = RunOneRayTiltSource(Lamd,Nsize,spo,thetmirr)
#with open("Plots/OneRayI"+str(XY)+str(Lamd)+'mm'+time.strftime("_%Y_%m_%d_%H_%M_%S") + ".pkl", "wb") as f:
    #pickle.dump(Ij,f)
#with open("Plots/OneRayD"+str(XY)+str(Lamd)+'mm'+time.strftime("_%Y_%m_%d_%H_%M_%S") + ".pkl", "wb") as f:
    #pickle.dump(Delay,f)
Timef = time.time()
print('total time: ~',float(Timef-Timei)/60, 'mins')
pl.plot(Delay,Ij,linewidth = .8) 
pl.tick_params(colors = 'black')
pl.title('$\lambda$='+str(Lamd),color = 'black')
pl.xlabel('Optical Delay (mm)', color = 'black')
pl.show()

# %%
#now messing around with Nsize??? like trying to UNDERSAMPLE
Timei = time.time()
print('Running')
Lamd = 1.01
Nsize = Nsized(Lamd)
#Nsize = 512
#Nsize = 8192
Freq = float(300/Lamd)
spo = [-160.375,-113.,-80.0] #global CENTERED
#spo1 = [-152.4375, -113.0,-80.]
#XY = [spo1[0],spo1[1]]
#print(XY)
#p1 = np.pi/4.2 #off by 0.03739991254
#p2 = np.pi/2.2
#p3 = np.pi/1.2
#p4 = np.pi/3.8
thetmirr = [0.0,0.0, -np.pi/200] 
v = [0.,0.,1.]
Delay,Ij = RunOneRayTiltSource(Lamd,Nsize,spo,thetmirr)
#with open("Plots/OneRayI"+str(XY)+str(Lamd)+'mm'+time.strftime("_%Y_%m_%d_%H_%M_%S") + ".pkl", "wb") as f:
    #pickle.dump(Ij,f)
#with open("Plots/OneRayD"+str(XY)+str(Lamd)+'mm'+time.strftime("_%Y_%m_%d_%H_%M_%S") + ".pkl", "wb") as f:
    #pickle.dump(Delay,f)
Timef = time.time()
print('total time: ~',float(Timef-Timei)/60, 'mins')
pl.plot(Delay,Ij,linewidth = .8) 
pl.tick_params(colors = 'black')
pl.title('$\lambda$='+str(Lamd),color = 'black')
pl.xlabel('Optical Delay (mm)', color = 'black')
pl.show()

# %%
#now messing around with Nsize??? like trying to UNDERSAMPLE
Timei = time.time()
print('Running')
Lamd = 3.32
Nsize = Nsized(Lamd)
#Nsize = 512
#Nsize = 8192
#Freq = float(300/Lamd)
spo = [-160.375,-113.,-80.0] #global CENTERED
#spo1 = [-152.4375, -113.0,-80.]
#XY = [spo1[0],spo1[1]]
#print(XY)
#p1 = np.pi/4.2 #off by 0.03739991254
#p2 = np.pi/2.2
#p3 = np.pi/1.2
#p4 = np.pi/3.8
thetmirr = [0.0,0.0, -np.pi/200] 
v = [0.,0.,1.]
Delay,Ij = RunOneRayTiltSource(Lamd,Nsize,spo,thetmirr)
#with open("Plots/OneRayI"+str(XY)+str(Lamd)+'mm'+time.strftime("_%Y_%m_%d_%H_%M_%S") + ".pkl", "wb") as f:
    #pickle.dump(Ij,f)
#with open("Plots/OneRayD"+str(XY)+str(Lamd)+'mm'+time.strftime("_%Y_%m_%d_%H_%M_%S") + ".pkl", "wb") as f:
    #pickle.dump(Delay,f)
Timef = time.time()
print('total time: ~',float(Timef-Timei)/60, 'mins')
pl.plot(Delay,Ij,linewidth = .8) 
pl.tick_params(colors = 'black')
pl.title('$\lambda$='+str(Lamd),color = 'black')
pl.xlabel('Optical Delay (mm)', color = 'black')
pl.show()

# %% [markdown]
# #including tilting OF MIRROR
# '''REFLECTION OF A RAY OFF OF A MIRROR THAT IS PRESUMABLY TILTED'''
# #Ray_M0 = IntM2(Ray_E1,thetmirr, coeffmirr, originM) #off mirror
# def IntM2tilt(Ray,thetmirr,coeffmirr,originmirr):
#     if Ray is None:
#         return
#     p = Ray[2]
#     v = Ray[3]
#     Ray_M = []
#     Ray_M.append(Ray[0])
#     Ray_M.append(Ray[1])
#     if (np.abs(thetmirr[0]) + np.abs(thetmirr[1]) + np.abs(thetmirr[2])) == 0.0:
#         return IntM2(Ray,coeffmirr,originmirr)
#     else:
#         p1,v1 = RT(p,v,thetG,originG,thetmirr,originmirr) #LOCAL
#         intpoint = PLINTyS(originmirr[1],p1,v1)
#         if SRM(intpoint,coeffmirr,originmirr) == True:
#             VectLNorm = N(v1) #local
#             PNormpos = [0,-1,0] #from definition of mirror (check sign what)
#             PNormneg = [0,1,0] #what
#             VectReflectpos = VectLNorm -2*N(PNormpos)*(np.dot(VectLNorm,N(PNormpos))) #Local
#             VectReflectneg = VectLNorm -2*N(PNormneg)*(np.dot(VectLNorm,N(PNormneg)))
#             GoodInt,GoodVect = finddirec(p1,v1,intpoint,intpoint,VectReflectpos,VectReflectneg)
#             p2,v2 = RT(GoodInt,GoodVect,thetmirr,originmirr,thetG,originG) #NOW GLOBAL
#             Ray_M.append(p2)
#             Ray_M.append(v2) #change to reflected
#             Df = dist(p,GoodInt) #ADDING DISTANCE TRAVELLED (ADDED 4/21)
#             Ray_M.append(Ray[4]+Df)
#             return Ray_M
#         else:
#             return
# def RunOneRayTiltSource(Lamd,Nsize,spo,v,thetmirr):
#     n = 1
#     r = 0
#     #Rays = makeraysTILT(spo,r,n,v)
#     Rays = makeraysVERTICAL(spo,r,n)
#     jx,jy = gridlines(7.9375,[160.375,-113],200) #these are now the PIXELS
#     Pix = MakePixels(jx,jy) #center of each pixel
#     Ij = []
#     Delay = []
#     for y in np.linspace(-18,18,int(Nsize)):
#         PTot=0
#         OutRays=RunRaysMtilt(Rays,y,thetmirr) #eight each
#         for j in range(len(Pix)): #per PIXEL
#             Ex4i = 0 #adding PER PIXEL from parts of RAYS in this PIXEL
#             Ey4i = 0 #THIS IS WHERE THEY WILL INTERFERE
#             for i in range(len(OutRays)): #per ray IN THIS PIXEL
#                 I = OutRays[i][1]
#                 thet = OutRays[i][0]
#                 phase = np.exp(1j*(OutRays[i][4]*2*np.pi/Lamd)) #factor of 2??
#                 Ex1 = np.sqrt(I)*np.cos(thet)
#                 Ey1 = np.sqrt(I)*np.sin(thet)
#                 Ex = Ex1*phase
#                 Ey = Ey1*phase
#                 #doing summation over entire detector
#                 sig,mux,muy = MakeGaussian(OutRays[i],Lamd)
#                 Gr = Airygaussian3dNORM(Pix[j][0],Pix[j][1],sig,mux,muy)
#                 Ex4i = Ex4i + Gr*Ex
#                 Ey4i = Ey4i + Gr*Ey
#             PTot = PTot + (Ex4i*Ex4i.conjugate()).real + (Ey4i*Ey4i.conjugate()).real
#         Delay.append(y*0.95630475596*4)
#         Ij.append(PTot)
#     return Delay,Ij

# %% [markdown]
# def IntM2(Ray,coeffmirr,originmirr):
#     if Ray is None:
#         return
#     p = Ray[2]
#     v = Ray[3]
#     Ray_M = []
#     Ray_M.append(Ray[0])
#     Ray_M.append(Ray[1])
#     intpoint = PLINTyS(originmirr[1],p,v)
#     if SRM(intpoint,coeffmirr,originmirr) == True:
#         Ray_M.append(intpoint)
#         VectLNorm = N(v)
#         PNorm = [0,-1,0] #from definition of mirror (check sign what)
#         VectReflect = VectLNorm -2*N(PNorm)*(np.dot(VectLNorm,N(PNorm)))
#         Ray_M.append(VectReflect) #change to reflected
#         Df = dist(p,intpoint) #ADDING DISTANCE TRAVELLED (ADDED 4/21)
#         Ray_M.append(Ray[4]+Df)
#         return Ray_M
#     else:
#         return
# def IntM2tilt(Ray,thetmirr,coeffmirr,originmirr):
#     if Ray is None:
#         return
#     p = Ray[2]
#     v = Ray[3]
#     Ray_M = []
#     Ray_M.append(Ray[0])
#     Ray_M.append(Ray[1])
#     if (np.abs(thetmirr[0]) + np.abs(thetmirr[1]) + np.abs(thetmirr[2])) == 0.0:
#         return IntM2(Ray,coeffmirr,originmir)
#     else:
#         p1,v1 = RT(p,v,thetG,originG,thetmirr,originmirr) #LOCAL
#         intpoint = PLINTyS(originmirr[1],p1,v1)
#         if SRM(intpoint,coeffmirr,originmirr) == True:
#             VectLNorm = N(v1) #local
#             PNormpos = [0,-1,0] #from definition of mirror (check sign what)
#             PNormneg = [0,1,0] #what
#             VectReflectpos = VectLNorm -2*N(PNormpos)*(np.dot(VectLNorm,N(PNormpos))) #Local
#             VectReflectneg = VectLNorm -2*N(PNormneg)*(np.dot(VectLNorm,N(PNormneg)))
#             GoodInt,GoodVect = finddirec(p1,v1,intpoint,intpoint,VectReflectpos,VectReflectneg)
#             p2,v2 = RT(GoodInt,GoodVect,thetmirr,originmirr,thetG,originG) #NOW GLOBAL
#             Ray_M.append(p2)
#             Ray_M.append(v2) #change to reflected
#             Df = dist(p,GoodInt) #ADDING DISTANCE TRAVELLED (ADDED 4/21)
#             Ray_M.append(Ray[4]+Df)
#             return Ray_M
#         else:
#             return

# %%
import numpy as np
import matplotlib.pyplot as pl
import itertools
from mpl_toolkits.mplot3d import Axes3D
from RayTraceFunctions import *
from PossiblePaths import *
from BackgroundValues import *
from random import uniform
import random #you can do this Mira, I believe in you :) and you is still a doof 
import matplotlib
import pickle
import time #to save figs automatically time.strftime("%Y_%m_%d_%s")
#%matplotlib auto
from datetime import datetime

# %%
start = []
detz = []
Run =1
if Run ==1:
    n = 100
    r = 0.0
    st = [0.,0.,0.] #SHOT STRAIGHT UP
    Lamd = 3.3
    Nsize = 256
    spo = [-160.375,-113.,-80.0]
    Rays = makerays(spo,st,r,n)
    y = 0
    OutRays=RunRaysM(Rays,y) #eight each
    for i in range(len(OutRays)):
        detz.append(OutRays[i][2])
    #for y in np.linspace(-18,18,Nsize):
        #OutRays=RunRaysM(Rays,y) #eight each
        #for i in range(len(OutRays)):
            #detz.append(OutRays[i][2])

# %%
for i in range(len(detz)):
    pl.scatter(detz[i][0],detz[i][1])
x,yp,yn = circle([160.375,-113],7.9375)
pl.scatter(160.375,-113,marker = '*',color = 'black',s = 100,label = 'source point')
pl.plot(x,yp, color = 'black')
pl.plot(x,yn, color = 'black'),#label = 'r = 8mm')
pl.title('Decoherence')
pl.legend()
pl.savefig('Plots/Decoherence')
pl.show()

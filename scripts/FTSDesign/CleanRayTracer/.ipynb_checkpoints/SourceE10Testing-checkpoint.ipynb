# %% [markdown]
# Source off of E10. (see page 141). if this works, apply numbers from 141 to E7

# %%
import numpy as np
import matplotlib.pyplot as pl
import itertools
from mpl_toolkits.mplot3d import Axes3D
from RayTraceFunCleaner import *
from random import uniform
import random

# %%
origin10 = [-96.225,7.5,-40]
thet10 = [0,.310422,-1.3106]
#ELLIPSE 10
X11i,Y11i,Z11i,X12i,Y12i,Z12i = FTSEC(50,np.pi*2, coeffellipse7, 329.29, 'pos') #LOCAL
Xset11,Yset11,Zset11 = transformLG(X11i,Y11i,Z11i,origin10,thet10) #GLOBAL
Xset12,Yset12,Zset12 = transformLG(X12i,Y12i,Z12i,origin10,thet10) #GLOBAL
Ecenter10 = [-128.3,0,0] #GLOBAL SECTION
X11,Y11,Z11 = SR10(32.07, Xset11,Yset11,Zset11, Ecenter10) #SELECTED GLOBAL
X12,Y12,Z12 = SR10(32.07, Xset12,Yset12,Zset12, Ecenter10) #SELECTED GLOBAL
center10,range10, = xrangeGL6(X11,Y11,Z11,X12,Y12,Z12,origin10,thet10) #LOCAL RANGE 
X11t,Y11t,Z11t = SR103di(range10,X11i,Y11i,Z11i,center10) #LOCAL
X12t,Y12t,Z12t = SR103di(range10,X12i,Y12i,Z12i,center10) #LOCAL

# %%
originG = [0,0,0] #literally the global origin
origin10 = [-96.225,7.5,-40]
coeffellipse7 = [164.645,99.8,130.95] #for ellipse 7
thet10 = [0,.310422,-1.3106] #negative of thet7?

# %%
pl3dsurf = pl.figure().gca(projection = '3d')
pl3dsurf.plot(Xset11,Yset11,Zset11,linewidth = .2, antialiased=True, color = 'red',alpha=0.7)#GLOBAL
pl3dsurf.plot(Xset12,Yset12,Zset12,linewidth = .2, antialiased=True, color = 'red',alpha=0.7)#GLOBAL
pl.show()

# %%
pl.plot(Xset11,Yset11)
pl.show()
pl.plot(Yset11,Zset11)
pl.show()

# %% [markdown]
# a = [-2,4,-1,9]
# b = [10,11,12,13]
# c = []
# c.extend(a),c.extend(b)
# min(c)
# max(c)
# if (1 + 2 < 1
#     or 2 + 1 > 1 ):
#     print ('what')
# else:
#     print('duh')

# %%
def xrangeGL6 (x1,y1,z1,x3,y3,z3,origin,thet):
    x,y,z = [],[],[]
    x2,y2,z2 = transformGL(x1,y1,z1,origin,thet)
    x4,y4,z4 = transformGL(x3,y3,z3,origin,thet)
    x.extend(x2),x.extend(x4),y.extend(y2),y.extend(y4),z.extend(z2),z.extend(z4)
    
    xrangeL = np.sqrt((min(x) - max(x))**2)/2
    yrangeL = np.sqrt((min(y) - max(y))**2)/2
    zrangeL = np.sqrt((min(z) - max(z))**2)/2
    
    xcenter = min(x) + xrangeL
    ycenter = min(y) + yrangeL
    zcenter = min(z) + zrangeL
    
    xcenterL = [xcenter,ycenter,zcenter]
    xrangesL = [xrangeL,yrangeL,zrangeL]
    return xcenterL,xrangesL
def SR103di(ranges,X,Y,Z, origin): #this corrects SR103d
    xintG = []
    yintG = []
    zintG = []
    xr = ranges[0]
    yr = ranges[1]
    zr = ranges[2]
    xc = origin[0]
    yc = origin[1]
    zc = origin[2]
    for i in range (0,len(X)):
        xinti = X[i]
        yinti = Y[i]
        zinti = Z[i]
        if ( ((xinti-xc)**2)/(xr**2) + ((yinti-yc)**2)/(yr**2) <= 1 
            and ((yinti-yc)**2)/(yr**2) + ((zinti-zc)**2)/(zr**2) <=1
            and ((zinti-zc)**2)/(zr**2) + ((xinti-xc)**2)/(xr**2) <=1):
            xintG.append(xinti)
            yintG.append(yinti)
            zintG.append(zinti)
    return xintG,yintG,zintG

# %%
X11i,Y11i,Z11i,X12i,Y12i,Z12i = FTSEC(50,np.pi*2, coeffellipse7, 329.29, 'pos') #LOCAL
Xset11,Yset11,Zset11 = transformLG(X11i,Y11i,Z11i,origin10,thet10) #GLOBAL
Xset12,Yset12,Zset12 = transformLG(X12i,Y12i,Z12i,origin10,thet10) #GLOBAL
Ecenter = [-128.3,0,0]
X11,Y11,Z11 = SR10(32.07, Xset11,Yset11,Zset11, Ecenter) #SELECTED GLOBAL
X12,Y12,Z12 = SR10(32.07, Xset12,Yset12,Zset12, Ecenter) #SELECTED GLOBAL

# %% [markdown]
# #MESSING WITH xrangeGL
# def xrangeGL (x1,y1,z1,origin,thet):
#     x2,y2,z2 = transformGL(x1,y1,z1,origin,thet)
#     xcenter = (min(x2) + max(x2))/2
#     ycenter = (min(y2) + max(y2))/2
#     zcenter = (min(z2) + max(z2))/2
#     xrangeL = (abs(min(x2)) + abs(max(x2)))/2
#     xcenterL = [xcenter,ycenter,zcenter]
#     return xcenterL,xrangeL
# #have to deal with rotation??

# %%
#getting xranges correct
#using transformed (from G-L) section chosen, getting ranges in Local
center10,range10, = xrangeGL6(X11,Y11,Z11,X12,Y12,Z12,origin10,thet10)
print(range10)
print(center10)

X11t,Y11t,Z11t = SR103di(range10,X11i,Y11i,Z11i,center10)
X12t,Y12t,Z12t = SR103di(range10,X12i,Y12i,Z12i,center10)
# Out:
# [41.577020202020208, 32.523395696802737, 19.579712527288851]
# [-96.458686868686868, 3.8644349946904448, 73.727355323017733]

# %%
#attempt at E7
#X11i,Y11i,Z11i,X12i,Y12i,Z12i = FTSEC(50,np.pi*2, coeffellipse7, 329.29, 'pos') #LOCAL
#haven't actually calculated, just testing angle
origin7 = [160.375,-7.5,40]
thet7 = [0,.319422,1.3106] #I THINK 
X7i,Y7i,Z7i,X8i,Y8i,Z8i = FTSEC(50,np.pi*2, coeffellipse7, 329.29, 'pos')
Xset7,Yset7,Zset7 = transformLG(X7i,Y7i,Z7i,origin7,thet7)
Xset8,Yset8,Zset8 = transformLG(X8i,Y8i,Z8i,origin7,thet7)
Ecenter = [192.45,0,0]
X7,Y7,Z7 = SR10(32.07,Xset7, Yset7, Zset7, Ecenter)
X8,Y8,Z8 = SR10(32.07,Xset8, Yset8, Zset8, Ecenter)

xcenter7,xrange7 = xrangeGL6(X7,Y7,Z7,X8,Y8,Z8,origin7,thet7)
X7t,Y7t,Z7t = SR103di(xrange7,X7,Y7,Z7,xcenter7)
X8t,Y8t,Z8t = SR103di(xrange7,X7,Y7,Z7,xcenter7)

pl3dsurf = pl.figure().gca(projection = '3d')
pl3dsurf.plot(Xset7,Yset7,Zset7,linewidth = .2, antialiased=True, color = 'red',alpha=0.7)#GLOBAL
pl3dsurf.plot(Xset8,Yset8,Zset8,linewidth = .2, antialiased=True, color = 'red',alpha=0.7)#GLOBAL
pl3dsurf.scatter(X7,Y7,Z7, marker = 'o', color = 'black')
pl3dsurf.scatter(X8,Y8,Z8, marker = 'o', color = 'black')
pl.show()
#the ellipse and the two foci

# %%
pl.plot(Xset7,Yset7)
pl.show()
pl.plot(Yset7,Zset7)
pl.show()

# %%
pl3dsurf = pl.figure().gca(projection = '3d')
pl3dsurf.plot(Xset11,Yset11,Zset11,linewidth = .2, antialiased=True, color = 'red',alpha=0.7)#GLOBAL
pl3dsurf.plot(Xset12,Yset12,Zset12,linewidth = .2, antialiased=True, color = 'red',alpha=0.7)#GLOBAL
pl3dsurf.scatter([-128.3],[-113],[-80], color = 'green')
pl3dsurf.scatter([-64.15],[128],[0], color = 'blue')
pl.show()
#the ellipse and the two foci

# %%
#TRYING to use sr103D

pl3dsurf = pl.figure().gca(projection = '3d')
pl3dsurf.scatter(X11,Y11,Z11,linewidth = .2, antialiased=True, color = 'black')#GLOBAL
pl3dsurf.scatter(X12,Y12,Z12,linewidth = .2, antialiased=True, color = 'black')#GLOBAL

pl3dsurf.plot(Xset11,Yset11,Zset11,linewidth = .2, antialiased=True, color = 'red',alpha=0.7)#GLOBAL
pl3dsurf.plot(Xset12,Yset12,Zset12,linewidth = .2, antialiased=True, color = 'red',alpha=0.7)#GLOBAL

pl3dsurf.plot(X11i,Y11i,Z11i,linewidth = .2, antialiased=True, color = 'blue',alpha=0.7)#LOCAL
pl3dsurf.plot(X12i,Y12i,Z12i,linewidth = .2, antialiased=True, color = 'blue',alpha=0.7)#LOCAL

pl3dsurf.scatter(X11t,Y11t,Z11t,linewidth = .2, antialiased=True, color = 'black')#LOCAL
pl3dsurf.scatter(X12t,Y12t,Z12t,linewidth = .2, antialiased=True, color = 'black')#LOCAL
pl.title('using xrange')
pl.show()

#back to really simple basics: 
#just transform the points (ignoring range etc for now)
xt,yt,zt = transformGL(X11,Y11,Z11,origin10,thet10)
xt2,yt2,zt2 = transformGL(X12,Y12,Z12,origin10,thet10)
pl3dsurf = pl.figure().gca(projection = '3d')


pl3dsurf.scatter(X11,Y11,Z11,linewidth = .2, antialiased=True, color = 'black')#GLOBAL
pl3dsurf.scatter(X12,Y12,Z12,linewidth = .2, antialiased=True, color = 'black')#GLOBAL

pl3dsurf.plot(Xset11,Yset11,Zset11,linewidth = .2, antialiased=True, color = 'red',alpha=0.7)#GLOBAL
pl3dsurf.plot(Xset12,Yset12,Zset12,linewidth = .2, antialiased=True, color = 'red',alpha=0.7)#GLOBAL

pl3dsurf.plot(X11i,Y11i,Z11i,linewidth = .2, antialiased=True, color = 'blue',alpha=0.7)#LOCAL
pl3dsurf.plot(X12i,Y12i,Z12i,linewidth = .2, antialiased=True, color = 'blue',alpha=0.7)#LOCAL

pl3dsurf.scatter(xt,yt,zt,linewidth = .2, antialiased=True, color = 'black')#LOCAL
pl3dsurf.scatter(xt2,yt2,zt2,linewidth = .2, antialiased=True, color = 'black')#LOCAL
pl.title('actual transform')
pl.show()

#OK THIS LOOKS RIGHT. SO FIGURE OUT HOW TO GET RANGE

#OK THE RANGE IS RIGHT

# %%
pl3dsurf = pl.figure().gca(projection = '3d')


pl3dsurf.scatter(X11,Y11,Z11,linewidth = .2, antialiased=True, color = 'black')#GLOBAL
pl3dsurf.scatter(X12,Y12,Z12,linewidth = .2, antialiased=True, color = 'black')#GLOBAL

pl3dsurf.plot(Xset11,Yset11,Zset11,linewidth = .2, antialiased=True, color = 'red',alpha=0.7)#GLOBAL
pl3dsurf.plot(Xset12,Yset12,Zset12,linewidth = .2, antialiased=True, color = 'red',alpha=0.7)#GLOBA
pl.show()

# %%
pl3dsurf = pl.figure().gca(projection = '3d')
pl3dsurf.scatter(X11,Y11,Z11,linewidth = .2, antialiased=True, color = 'black')#GLOBAL
pl3dsurf.scatter(X12,Y12,Z12,linewidth = .2, antialiased=True, color = 'black')#GLOBAL
pl.title('Global Section')
pl.show()

#GLOBAL

pl3dsurf = pl.figure().gca(projection = '3d')
pl3dsurf.scatter(xt,yt,zt,linewidth = .2, antialiased=True, color = 'green')#LOCAL (direct transformation)
pl3dsurf.scatter(xt2,yt2,zt2,linewidth = .2, antialiased=True, color = 'green')#LOCAL
pl3dsurf.set_xlim(-160,0)
pl3dsurf.set_zlim(20,100)
pl.title('G-L Transformed ')
pl.show()

pl3dsurf = pl.figure().gca(projection = '3d')
pl3dsurf.scatter(X11t,Y11t,Z11t,linewidth = .2, antialiased=True, color = 'white')#LOCAL
pl3dsurf.scatter(X12t,Y12t,Z12t,linewidth = .2, antialiased=True, color = 'blue')#LOCAL

pl.title('G-L xranged')
pl.show()
#direct vs indirect transformation
#OK INDIRECT WORKED SO USING THIS (confirms SR103i that was written above^)
#LOCAL
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-13-4e81dd78b6ea> in <module>()
#       8
#       9 pl3dsurf = pl.figure().gca(projection = '3d')
# ---> 10 pl3dsurf.scatter(xt,yt,zt,linewidth = .2, antialiased=True, color = 'green')#LOCAL (direct transformation)
#      11 pl3dsurf.scatter(xt2,yt2,zt2,linewidth = .2, antialiased=True, color = 'green')#LOCAL
#      12 pl3dsurf.set_xlim(-160,0)
#
# NameError: name 'xt' is not defined

# %% [markdown]
# pl3dsurf = pl.figure().gca(projection = '3d')
# pl3dsurf.plot(X11i,Y11i,Z11i,linewidth = .2, antialiased=True, color = 'blue',alpha=0.7)#LOCAL
# pl3dsurf.plot(X12i,Y12i,Z12i,linewidth = .2, antialiased=True, color = 'blue',alpha=0.7)#LOCAL
# pl3dsurf.scatter(X11t,Y11t,Z11t,linewidth = .2, antialiased=True, color = 'black')#LOCAL
# pl3dsurf.scatter(X12t,Y12t,Z12t,linewidth = .2, antialiased=True, color = 'black')#LOCAL
# pl3dsurf.plot([-130.95],[0],[0],marker = 'o', color = 'red')
# pl.show()
# #the limited (as opposed to transformed) is greater area. incorrect.

# %%
def ELI(pli,v1,coeffellipse):
    A = (1/coeffellipse[0]**2) + (v1[1]**2)/((v1[0]**2)*(coeffellipse[1])**2) + (v1[2]**2)/((v1[0]**2)*(coeffellipse[1]**2))
    B1 = -(2*pli[0]*(v1[1]**2))/((v1[0]**2)*(coeffellipse[1])**2) -(2*pli[0]*(v1[2]**2))/((v1[0]**2)*coeffellipse[1]**2)
    B2 = (2*v1[1]*pli[1])/((v1[0])*coeffellipse[1]**2)+ (2*v1[2]*pli[2])/((v1[0])*coeffellipse[1]**2)
    B = B1 + B2
    C1 = ((pli[0]**2)*(v1[1]**2))/((v1[0]**2)*coeffellipse[1]**2) + ((pli[0]**2)*(v1[2]**2))/((v1[0]**2)*coeffellipse[1]**2)
    C2 = -(2*pli[0]*v1[1]*pli[1])/((v1[0])*(coeffellipse[1]**2)) -(2*pli[0]*v1[2]*pli[2])/((v1[0])*(coeffellipse[1]**2))
    C3 = (pli[2]**2)/(coeffellipse[1]**2) + (pli[2]**2)/(coeffellipse[1]**2)
    C = C1 + C2 + C3 - 1
    xint = [(-B + np.sqrt(B**2 - 4*A*C))/(2*A),(-B - np.sqrt(B**2 - 4*A*C))/(2*A)]
    yint = [((xint[0] - pli[0])/(v1[0]))*v1[1] + pli[1],((xint[1] - pli[0])/(v1[0]))*v1[1] + pli[1]]
    zint = [((xint[0] - pli[0])/(v1[0]))*v1[2] + pli[2], ((xint[1] - pli[0])/(v1[0]))*v1[2] + pli[2]]
    return xint,yint,zint

# %%
x,y,z = ELI([0,0,0],[1,1,1],[1,1,np.sqrt(2)])
c = TC([0,0,0],[1,1,1],[1,1,np.sqrt(2)])
c

# %%
''' SetRange3Both (SR3B): simply changing requirements. same as SR3IC but only if a point is within an ellipse.'''
def SR3B (ranges, xinti,yinti,zinti, origin): #given range, one point, origin, if it lies in or not
    xr = ranges[0]
    yr = ranges[1]
    zr = ranges[2]
    xc = origin[0]
    yc = origin[1]
    zc = origin[2]
    if ( ((xinti-xc)**2)/(xr**2) + ((yinti-yc)**2)/(yr**2) <= 1 
        and ((yinti-yc)**2)/(yr**2) + ((zinti-zc)**2)/(zr**2) <=1
        and ((zinti-zc)**2)/(zr**2) + ((xinti-xc)**2)/(xr**2) <=1):
        return True
    return False

#NOW JUST USING SIGN TO MEAN IF POS OR NEG SIDE OF X
def REPCNi(coeffellipse,pli,v, sign):
    c = TC(pli,v,coeffellipse) #plane coefficients
    cpos = c[0]
    cneg = c[1]
    VectL = v
    VectLNorm = N(v) #incident unit vector
    dU, Npos = PI(cpos) #gradient and normal of plane of positive int
    dUneg,Nneg = PI(cneg)
    VectL2 = VectLNorm - 2*Npos*(np.dot(Npos,VectLNorm))
    VectL2neg = VectLNorm - 2*Nneg*(np.dot(Npos,VectLNorm))
    xint,yint,zint = ELI(pli,v,coeffellipse)
    if VectL2[0]<0 and VectL2[2]>0:
        VectL2 = [-x for x in VectL2]
    if VectL2neg[0]<0 and VectL2neg[2]>0:
        VectL2neg = [-x for x in VectL2neg]
    #check if it is going in the right direction for negative int
    pointint = [float(xint[0]),float(yint[0]),float(zint[0])] #array and points of intersection
    pointintneg = [float(xint[1]),float(yint[1]),float(zint[1])] #array and points of intersection
    #L1 = np.sqrt((pointint[0] - pli[0])**2 + (pointint[1] - pli[1])**2 + (pointint[2] - pli[2])**2)
    #L1neg = np.sqrt((pointintneg[0] - pli[0])**2 + (pointintneg[1] - pli[1])**2 + (pointintneg[2] - pli[2])**2)
    return pointint, pointintneg, VectL2, VectL2neg, #-Npos,-Nneg

def REPCN(coeffellipse,pli,v, sign):
    c = TC(pli,v,coeffellipse) #plane coefficients
    cpos = c[0]
    cneg = c[1]
    VectL = v
    VectLNorm = N(v) #incident unit vector
    dU, Npos = PI(cpos) #gradient and normal of plane of positive int
    dUneg, Nneg = PI(cneg)
    VectL2 = VectLNorm - 2*Npos
    VectL2neg = VectLNorm-2*Nneg
    #check if it is going in the right direction for positive int
    if sign == 'neg' and VectL2[1] < 0 : 
        VectL2 = [-x for x in VectL2]
    if sign == 'pos' and VectL2[1] > 0:
        VectL2 = [-x for x in VectL2]
    #check if it is going in the right direction for negative int
    if sign == 'neg' and VectL2neg[1] < 0 : 
        VectL2neg = [-x for x in VectL2neg]
    if sign == 'pos' and VectL2neg[1] > 0:
        VectL2neg = [-x for x in VectL2neg]
    xint,yint,zint = ELI(pli,v,coeffellipse)
    pointint = [float(xint[0]),float(yint[0]),float(zint[0])] #array and points of intersection
    pointintneg = [float(xint[1]),float(yint[1]),float(zint[1])] #array and points of intersection
    #L1 = np.sqrt((pointint[0] - pli[0])**2 + (pointint[1] - pli[1])**2 + (pointint[2] - pli[2])**2)
    #L1neg = np.sqrt((pointintneg[0] - pli[0])**2 + (pointintneg[1] - pli[1])**2 + (pointintneg[2] - pli[2])**2)
    return pointint, pointintneg, VectL2, VectL2neg

def RSEPCN2(coeffellipse,pli,vectors, ranges, origin,sign):
    Vect = []
    pointints = []
    if len(pli) == 0:
        return [],[]
    if type(pli[0]) is int or type(pli[0]) is float: #assuming it is a source from one point
        for i in range (0,len(vectors)):
            pointint, pointintneg,VectL2, VectL2neg = REPCNi(coeffellipse,pli,vectors[i], sign)
            if SR3B(ranges, pointint[0], pointint[1], pointint[2], origin) == True: 
                pointints.append(pointint)
                Vect.append(VectL2)
            if SR3B(ranges, pointintneg[0], pointintneg[1], pointintneg[2], origin) == True:
                pointints.append(pointintneg)
                Vect.append(VectL2neg)
    else:
        for i in range (0, len(vectors)):
            Vi = vectors[i]
            Pli = pli[i] #(or pli/original points of lines)
            #pointint, pointintneg, vectL2, vectL2neg,VNp,VNn = REPCN(coeffellipse,Pli,Vi, sign)
            pointint, pointintneg,VectL2, VectL2neg = REPCNi(coeffellipse,Pli,Vi, sign)

            if SR3B(ranges, pointint[0], pointint[1], pointint[2], origin) == True: 
                pointints.append(pointint) 
                Vect.append(VectL2)
            if SR3B(ranges, pointintneg[0], pointintneg[1], pointintneg[2], origin) == True:
                pointints.append(pointintneg)
                Vect.append(VectL2neg)
    return pointints,Vect

# %%
#source 1 being reflected off of E10
originL = [0,0,0] #locally (or the global origin)
thetL = [0,0,0]

#creating the source (around the focus of E8) LOCALLY 
sourcepointorigin = [-130.95,0,0] #locally 
#sourcethet = [-np.pi/2,0,-.310422] #locally
sourcethet = [0,0,0]
sourcepoints = specsource(8,sourcepointorigin,sourcethet) #local

#source point and vector!
sourcep1, sv1 = FS(100,sourcepoints, sourcethet,origin10) #local
#Reflection off of E10
points10, vects10 = RSEPCN2(coeffellipse7,sourcep1,sv1, range10,center10,'pos') #local

# %%
pl3dsurf = pl.figure().gca(projection = '3d')

pl3dsurf.plot(X11i,Y11i,Z11i,linewidth = .2, antialiased=True, color = 'blue',alpha=0.7)#LOCAL
pl3dsurf.plot(X12i,Y12i,Z12i,linewidth = .2, antialiased=True, color = 'blue',alpha=0.7)#LOCAL

for i in range (0,len(points10)):
    x,y,z = ML(points10[i],vects10[i],80)
    pl.plot(x,y,z,color = 'red')
pl.show()
#SHOULD be hitting the target correctly
#normals are backwards

# %%
#local
pl3dsurf = pl.figure().gca(projection = '3d')
#pl3dsurf.plot(X11i,Y11i,Z11i,linewidth = .2, antialiased=True, color = 'blue',alpha=0.7)#LOCAL
#pl3dsurf.plot(X12i,Y12i,Z12i,linewidth = .2, antialiased=True, color = 'blue',alpha=0.7)#LOCAL
pl3dsurf.plot(X11i,Y11i,Z11i,linewidth = .2, antialiased=True, color = 'blue',alpha=0.7)#LOCAL
pl3dsurf.plot(X12i,Y12i,Z12i,linewidth = .2, antialiased=True, color = 'blue',alpha=0.7)#LOCAL
#for i in range (0,len(sourcep1)):
    #x,y,z = ML(sourcep1[i],sv1[i],80)
    #pl.plot(x,y,z,color = 'red')
for i in range (0,len(points10)):
    x,y,z = ML(points10[i],vects10[i],100)
    pl.plot(x,y,z, color = 'blue')
#for i in range (0,len(NORMS)):
    #x,y,z = ML(points10[i],NORMS[i],100)
    #pl.plot(x,y,z, color = 'black')
for i in range (0,len(points10)):
    pl3dsurf.scatter([points10[i][0]],[points10[i][1]],[points10[i][2]],color = 'green')
    
pl.show()
#intersection is off too
#something is clearly wrong

# %%
pl3dsurf = pl.figure().gca(projection = '3d')
pl3dsurf.plot(X11i,Y11i,Z11i,linewidth = .2, antialiased=True, color = 'blue',alpha=0.7)#LOCAL
pl3dsurf.plot(X12i,Y12i,Z12i,linewidth = .2, antialiased=True, color = 'blue',alpha=0.7)#LOCAL
pl3dsurf.scatter(X11t,Y11t,Z11t,linewidth = .2, antialiased=True, color = 'black')#LOCAL
pl3dsurf.scatter(X12t,Y12t,Z12t,linewidth = .2, antialiased=True, color = 'black')#LOCAL
pl3dsurf.scatter([-130.95],[0],[0], color = 'yellow')
pl3dsurf.scatter([130.95],[0],[0], color = 'yellow')
for i in range (0,len(points10)):
    x,y,z = ML(points10[i],vects10[i],200)
    pl.plot(x,y,z, color = 'red')
pl.show()
#ok so i'm obviously doing something wrong and I don't know what.
#it seems to be reflecting as if from the outside!? doesn't seem right.
#track through entire code to find problem...

# %%
pl3dsurf = pl.figure().gca(projection = '3d')

pl3dsurf.scatter(xt,yt,zt,linewidth = .2, antialiased=True, color = 'black')#LOCAL (direct transformation)
pl3dsurf.scatter(xt2,yt2,zt2,linewidth = .2, antialiased=True, color = 'black')#LOCAL
pl3dsurf.scatter([-130.95],[0],[0], color = 'yellow')
pl3dsurf.scatter([130.95],[0],[0], color = 'yellow')
for i in range (0,len(points10)):
    x,y,z = ML(points10[i],vects10[i],200)
    pl.plot(x,y,z, color = 'red')
pl.show()

# %% [markdown]
# pl3dsurf = pl.figure().gca(projection = '3d')
# #pl3dsurf.plot(X11i,Y11i,Z11i,linewidth = .2, antialiased=True, color = 'blue',alpha=0.7)#LOCAL
# #pl3dsurf.plot(X12i,Y12i,Z12i,linewidth = .2, antialiased=True, color = 'blue',alpha=0.7)#LOCAL
#
# pl3dsurf.scatter(X11t,Y11t,Z11t,linewidth = .2, antialiased=True, color = 'black')#LOCAL
# pl3dsurf.scatter(X12t,Y12t,Z12t,linewidth = .2, antialiased=True, color = 'black')#LOCAL
# for i in range (0,len(sourcep1)):
#     x,y,z = ML(sourcep1[i],sv1[i],100)
#     pl.plot(x,y,z)
# pl.show()

# %%
#simply testing intersection
sourcepointorigin = [-130.95,0,0] #locally 
#sourcethet = [-np.pi/2,0,-.310422] #locally
sourcethet = [0,0,0]
sourcepoints = specsource(8,sourcepointorigin,sourcethet) #local
s1, v1 = FS(10,sourcepoints, sourcethet,origin10) #local

pl3dsurf = pl.figure().gca(projection = '3d')
pl3dsurf.plot(X11i,Y11i,Z11i,linewidth = .2, antialiased=True, color = 'blue',alpha=0.7)#LOCAL
pl3dsurf.plot(X12i,Y12i,Z12i,linewidth = .2, antialiased=True, color = 'blue',alpha=0.7)#LOCAL
for i in range (0,len(s1)):
    x,y,z = ML(s1[i],v1[i],80)
    pl.plot(x,y,z,color = 'red')
pl.show()
#now finding intersection points for each of the 10 rays

# %% [markdown]
# pl3dsurf = pl.figure().gca(projection = '3d')
# pl3dsurf.plot(X11i,Y11i,Z11i,linewidth = .2, antialiased=True, color = 'blue',alpha=0.7)#LOCAL
# pl3dsurf.plot(X12i,Y12i,Z12i,linewidth = .2, antialiased=True, color = 'blue',alpha=0.7)#LOCAL
# for i in range (0,len(v1)):
#     x,y,z = ML([-130.95,0,0],v1[i],50)
#     pl3dsurf.plot(x,y,z, color = 'red')
# pl3dsurf.set_xlim(-150,-120)
# pl3dsurf.set_zlim(0,75)
# pl3dsurf.set_ylim(-50,50)
# pl.show()

# %%
pl3dsurf = pl.figure().gca(projection = '3d')
pl3dsurf.plot(X11i,Y11i,Z11i,linewidth = .2, antialiased=True, color = 'blue',alpha=0.7)#LOCAL
pl3dsurf.plot(X12i,Y12i,Z12i,linewidth = .2, antialiased=True, color = 'blue',alpha=0.7)#LOCAL
for i in range(0,len(s1)):
    x,y,z = ELI(s1[i],v1[i],coeffellipse7)
    if x[0] <=0 and z[0]>=0:
        pl3dsurf.scatter([x[0]],[y[0]],[z[0]])
    if x[1] <=0  and z[0]>=0:
        pl3dsurf.scatter([x[1]],[y[1]],[z[1]])
    print (x)
pl.show()

# %%
p = [-130,0,0]
V = [1,.001,1]
v = N(V)
x,y,z = ELI(p,v,coeffellipse7)
pl3dsurf = pl.figure().gca(projection = '3d')
pl3dsurf.plot(X11i,Y11i,Z11i,linewidth = .2, antialiased=True, color = 'blue',alpha=0.7)#LOCAL
pl3dsurf.plot(X12i,Y12i,Z12i,linewidth = .2, antialiased=True, color = 'blue',alpha=0.7)#LOCAL
pl3dsurf.scatter([x[0]],[y[0]],[z[0]], color ='black')
pl3dsurf.scatter([x[1]],[y[1]],[z[1]], color = 'black')
x1,y1,z1 = ML(p,v,300)
pl3dsurf.plot(x1,y1,z1)
pl.show()
#why does this seem slightly off?
#somethnig is wrong regarding origin?

# %%
def ELI(pli,v1,coeffellipse):
    A = (1/coeffellipse[0]**2) + (v1[1]**2)/((v1[0]**2)*(coeffellipse[1])**2) + (v1[2]**2)/((v1[0]**2)*(coeffellipse[1]**2))
    B1 = -(2*pli[0]*(v1[1]**2))/((v1[0]**2)*(coeffellipse[1])**2) -(2*pli[0]*(v1[2]**2))/((v1[0]**2)*coeffellipse[1]**2)
    B2 = (2*v1[1]*pli[1])/((v1[0])*coeffellipse[1]**2)+ (2*v1[2]*pli[2])/((v1[0])*coeffellipse[1]**2)
    B = B1 + B2
    C1 = ((pli[0]**2)*(v1[1]**2))/((v1[0]**2)*coeffellipse[1]**2) + ((pli[0]**2)*(v1[2]**2))/((v1[0]**2)*coeffellipse[1]**2)
    C2 = -(2*pli[0]*v1[1]*pli[1])/((v1[0])*(coeffellipse[1]**2)) -(2*pli[0]*v1[2]*pli[2])/((v1[0])*(coeffellipse[1]**2))
    C3 = (pli[2]**2)/(coeffellipse[1]**2) + (pli[2]**2)/(coeffellipse[1]**2)
    C = C1 + C2 + C3 - 1
    xint = [(-B + np.sqrt(B**2 - 4*A*C))/(2*A),(-B - np.sqrt(B**2 - 4*A*C))/(2*A)]
    yint = [((xint[0] - pli[0])/(v1[0]))*v1[1] + pli[1],((xint[1] - pli[0])/(v1[0]))*v1[1] + pli[1]]
    zint = [((xint[0] - pli[0])/(v1[0]))*v1[2] + pli[2], ((xint[1] - pli[0])/(v1[0]))*v1[2] + pli[2]]
    return xint,yint,zint 

def NormalP(pli,v1,coeffellipse):
    xint1, yint1, zint1 = ELI(pli,v1,coeffellipse)
    cpos = [(2*xint1[0])/(coeffellipse[0]**2),(2*yint1[0])/(coeffellipse[1]**2),(2*zint1[0])/(coeffellipse[1]**2)]
    cneg = [(2*xint1[1])/(coeffellipse[0]**2),(2*yint1[1])/(coeffellipse[1]**2),(2*zint1[1])/(coeffellipse[1]**2)]
    cpos = np.array(cpos)
    cneg = np.array(cneg)
    return cpos,cneg

# %%
#NOW JUST USING SIGN TO MEAN IF POS OR NEG SIDE OF X
pli1 = [-5.001,0,0] #focus of ellipse (starting point of ray)
v1 = [-1,.1,1] # vector of point
coeffellipse1 = [np.sqrt(50),5,5] #a,b,c of ellipse that is rotated around x
Npos,Nneg = NormalP(pli1,v1,coeffellipse1) #plane coefficients
VectLNorm = N(v1) #incident unit vector
#dU, Npos = PI(cpos) #gradient and normal of plane of positive int (?)
#dUneg,Nneg = PI(cneg) #gradient and normal of plane of negative int (?)
#Npos = -Npos
Npos = np.array([-x for x in Npos])
Nneg = np.array([-x for x in Nneg])

VectL2 = VectLNorm - 2*N(Npos)*(np.dot(VectLNorm,N(Npos)))
VectL2neg = VectLNorm - 2*N(Nneg)*(np.dot(VectLNorm,N(Nneg)))
xint,yint,zint = ELI(pli1,v1,coeffellipse1)
#if VectL2[0]<0 and VectL2[2]>0:
    #VectL2 = [-x for x in VectL2]
#if VectL2neg[0]<0 and VectL2neg[2]>0:
    #VectL2neg = [-x for x in VectL2neg]
#check if it is going in the right direction for negative int
pointint = [float(xint[0]),float(yint[0]),float(zint[0])] #array and points of intersection
pointintneg = [float(xint[1]),float(yint[1]),float(zint[1])] #array and points of intersection
    #L1 = np.sqrt((pointint[0] - pli[0])**2 + (pointint[1] - pli[1])**2 + (pointint[2] - pli[2])**2)
    #L1neg = np.sqrt((pointintneg[0] - pli[0])**2 + (pointintneg[1] - pli[1])**2 + (pointintneg[2] - pli[2])**2)
#return pointint, pointintneg, VectL2, VectL2neg, #-Npos,-Nneg
X,Y,Z,X1,Y1,Z1 = FTSEC(50,np.pi*2, coeffellipse1, 14.142, 'pos') #LOCAL

# %%
pointint
pointintneg

# %%
pl3d = pl.figure().gca(projection = '3d')
pl3d.plot(X,Y,Z,linewidth = .2, antialiased=True, color = 'blue',alpha=0.7)#LOCAL
pl3d.plot(X1,Y1,Z1,linewidth = .2, antialiased=True, color = 'blue',alpha=0.7)#LOCAL

x,y,z = ML(pointint, Npos, 10) 
pl3d.plot(x,y,z, color = 'black')  #normal 1

x,y,z = ML(pointintneg,Nneg,10)
pl3d.plot(x,y,z, color = 'black')

f2 = [-5,0,0] #focus2
x,y,z = ML(f2,v1,5)
pl3d.plot(x,y,z,color = 'red') #initial ray

pl3d.scatter([pointint[0]],[pointint[1]],[pointint[2]], color = 'orange')
x,y,z = ML(pointint,VectL2,10)
pl3d.plot(x,y,z, color = 'orange') #reflected

pl3d.scatter([pointintneg[0]],[pointintneg[1]],[pointintneg[2]], color = 'yellow')
x,y,z = ML(pointintneg,VectL2neg,10)
pl3d.plot(x,y,z, color = 'yellow') #reflected



pl.show()

#FIGURE OUT WHEN YOU NEED INTPOS VS INT NEG

# %%
#SEEING THAT THIS WORKS, NOW USE IT FOR AN ENTIRE SOURCE

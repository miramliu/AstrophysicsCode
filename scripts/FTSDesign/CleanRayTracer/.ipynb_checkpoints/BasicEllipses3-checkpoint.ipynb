# %% [markdown]
# The four center ellipses and the reflections calculated using the new functions.
#
# ADD SIDE ELLIPSES
#
# Mira

# %%
import numpy as np
import matplotlib.pyplot as pl
import itertools
from mpl_toolkits.mplot3d import Axes3D
from RayTraceFunCleaner import *
from random import uniform
import random

# %%
#GLOBAL ORIGINS (MAKING THE CORRECT FTS)
originG = [0,0,0] #literally the global origin
origin1 = [0,-128,0] #x,y (ellipse1)
origin2 = [64.15,-128,0] #x,y (ellipse2)
origin3 = [0,128,0] #x,y (ellipse3)
origin4 = [64.15,128,0] #x,y  (ellipse4)
origin5 = [128.3,-120.501,0] # (ellipse5)
origin6 = [128.3,120.501,0] # (ellipse6)
origin7 = [192.45,0,40] # (ellipse7)
origin8 = [-64.15,-120.501,0]
origin9 = [-64.15,120.501,0]
origin10 = [-128.3,0,-40]

coeffellipse = [263.9,256,64.15] #for center ellipses
coeffellipse56 = [256.65,248.39,64.58]  #for ellipses 5&6
coeffellipse7 = [153,95.07,119.87] #for ellipse 7

thet = [0,0,0]
thet5 = [0,0,-.1164] 
thet6 = [0,0,.1164]
thet7 = [0,.3402,-np.pi/2] #rotated around z axis and y axis
thet10 = [0,-.3402,+np.pi/2] #negative of thet7?

#center ellipses
X1,Y1,Z1,X2,Y2,Z2 = FTSEC(50,np.pi/8, coeffellipse, 64.15, 'pos')
X1n,Y1n,Z1n,X2n,Y2n,Z2n = FTSEC(50,np.pi/8, coeffellipse, 64.15, 'neg')

Xset1, Yset1, Zset1 = SR2(32.07, X1,Y1,Z1, originG)
Xset2, Yset2, Zset2 = SR2(32.07, X2, Y2, Z2, originG)
Xset1n, Yset1n, Zset1n = SR2(32.07, X1n,Y1n,Z1n, originG)
Xset2n, Yset2n, Zset2n = SR2(32.07, X2n, Y2n, Z2n, originG)


#ellipse 1
X1i,Y1i,Z1i = transformLG(Xset1,Yset1,Zset1,origin1,thet)
X2i,Y2i,Z2i = transformLG(Xset2,Yset2,Zset2,origin1,thet)

#ellipse 3
X1n,Y1n,Z1n = transformLG(Xset1n,Yset1n,Zset1n,origin3,thet)
X2n,Y2n,Z2n = transformLG(Xset2n,Yset2n,Zset2n,origin3,thet)

#ellipse 2
X3i,Y3i,Z3i = transformLG(Xset1,Yset1,Zset1,origin2,thet)
X4i,Y4i,Z4i = transformLG(Xset2,Yset2,Zset2,origin2,thet)

#ellipse 4
X3n,Y3n,Z3n = transformLG(Xset1n,Yset1n,Zset1n,origin4,thet)
X4n,Y4n,Z4n = transformLG(Xset2n,Yset2n,Zset2n,origin4,thet)

#Side ellipses

#ellipse 5&6
X5,Y5,Z5,X6,Y6,Z6 = FTSEC(50,np.pi/8, coeffellipse56, 150, 'pos')
X5n,Y5n,Z5n,X6n,Y6n,Z6n = FTSEC(50,np.pi/8, coeffellipse56, 150, 'neg')

#ellipse5
Xset5, Yset5, Zset5= transformLG(X5,Y5,Z5,origin5,thet5)
Xset6, Yset6, Zset6 = transformLG(X6,Y6,Z6,origin5,thet5)

X5,Y5,Z5 = SR2(32.07, Xset5,Yset5,Zset5, origin5)
X6,Y6,Z6 = SR2(32.07, Xset6, Yset6, Zset6, origin5)

#ellipse6
Xset5n,Yset5n,Zset5n = transformLG(X5n,Y5n,Z5n,origin6,thet6)
Xset6n,Yset6n,Zset6n = transformLG(X6n,Y6n,Z6n,origin6,thet6)

X5n,Y5n,Z5n = SR2(32.07,Xset5n,Yset5n,Zset5n,origin6)
X6n,Y6n,Z6n = SR2(32.07,Xset6n,Yset6n,Zset6n,origin6)

#ellipse 7 
X7,Y7,Z7,X8,Y8,Z8 = FTSEC(50,np.pi*.99, coeffellipse7, 306, 'pos')
X7n,Y7n,Z7n,X8n,Y8n,Z8n = FTSEC(50,np.pi*.99, coeffellipse7, 306, 'neg')

Xset7,Yset7,Zset7 = transformLG(X7,Y7,Z7,origin7,thet7)
Xset8,Yset8,Zset8 = transformLG(X8,Y8,Z8,origin7,thet7)

X7,Y7,Z7 = SR7(32.07,Xset7, Yset7, Zset7, origin7)
X8,Y8,Z8 = SR7(32.07,Xset8, Yset8, Zset8, origin7)

#ellipse 8&9
X9,Y9,Z9,X10,Y10,Z10 = FTSEC(50,np.pi/8, coeffellipse56, 150, 'pos')
X9n,Y9n,Z9n,X10n,Y10n,Z10n = FTSEC(50,np.pi/8, coeffellipse56, 150, 'neg')

#ellipse 8
Xset9,Yset9,Zset9 = transformLG(X9,Y9,Z9,origin8,thet6)
Xset10,Yset10,Zset10 = transformLG(X10,Y10,Z10,origin8,thet6)

X9,Y9,Z9 = SR2(32.07, Xset9,Yset9,Zset9, origin8)
X10,Y10,Z10 = SR2(32.07, Xset10, Yset10, Zset10, origin8)

#ellipse 9
Xset9n,Yset9n,Zset9n = transformLG(X9n,Y9n,Z9n,origin9,thet5)
Xset10n,Yset10n,Zset10n = transformLG(X10n,Y10n,Z10n,origin9,thet5)

X9n,Y9n,Z9n = SR2(32.07, Xset9n,Yset9n,Zset9n, origin9)
X10n,Y10n,Z10n = SR2(32.07, Xset10n, Yset10n, Zset10n, origin9)

#ellipse 10
Xset11,Yset11,Zset11 = transformLG(X7n,Y7n,Z7n,origin10,thet10)
Xset12,Yset12,Zset12 = transformLG(X8n,Y8n,Z8n, origin10,thet10)

X11,Y11,Z11 = SR10(32.07, Xset11,Yset11,Zset11, origin10)
X12,Y12,Z12 = SR10(32.07, Xset12,Yset12,Zset12, origin10)

# %%
#source 1 (white rays)
xrange = 32
ellipseorigin = [0,0,0] #locally (or the global origin)
ellipsethetaxyz = [0,0,0]

#creating the source (around the focus of E1)
sourcepointorigin = [-64.15,-128,0] #globally 
sourcethet = [np.pi/2,0,.24553]
sourcepoints = specsource(8,sourcepointorigin,sourcethet)


#source point and vector!
sourcep1, sv1 = FS(1000,sourcepoints, sourcethet,origin1,)
sp1,v1 = RT(sourcep1,sv1,thet,ellipseorigin,thet,origin1)
#Reflection off of E1
points1, vects1 = RSEPCN(coeffellipse,sp1,v1, xrange, ellipseorigin,ellipsethetaxyz, 'pos')

# %%
#source (created by FS)
pl3dsurf = pl.figure().gca(projection = '3d')
for i in range (0,len(sv1)):
    x,y,z = ML(sourcep1[i], sv1[i], 200)
    pl3dsurf.plot(x,y,z, color = 'orange')
pl.show()

# %%
#Reflection off E3 from E1
sourcethetflat = [0,0,0] #transform angle (in this case 0)

#retransforming without changing angle at all
sp31, v31 = RT(points1,vects1,sourcethetflat,origin1, sourcethetflat,origin3)
#a = sepop(sp31[0], sp31[1], sp31[2])
#b = sepop(v31[0], v31[1], v31[2])
points31, vects31 = RSEPCN(coeffellipse, sp31,v31,xrange,ellipseorigin,ellipsethetaxyz, 'neg')
#should be none

# %%
#Reflection off E4 from E1
sp41, v41 = RT(points1,vects1,sourcethetflat,origin1,sourcethetflat,origin4)
points41, vects41 = RSEPCN(coeffellipse, sp41,v41,xrange,ellipseorigin,ellipsethetaxyz, 'neg')

# %%
#Reflection off of E5 from E4
origin5 = [128.3,-135.499,0]
coeffellipse56 = [263.91,255.886,64.58]
thet5 = [0,0,-.1164] 

sp54,v54 = RT(points41,vects41,sourcethetflat,origin4,thet5,origin5)
points54,vects54 = RSEPCN(coeffellipse, sp54,v54,xrange,ellipseorigin,ellipsethetaxyz,'pos')

# %%
#source 2 (everything local!!!)
xrange = 32
ellipseorigin = [0,0,0] #locally
ellipsethetaxyz = [0,0,0] #locally

#creating the source (around the focus of E8)
sourcepointorigin2 = [-128.3,-113,0] #AHHH locally?? globally?
sourcethet2 = [np.pi/2,0,.24553 + .1164] #same general direction as source1 + rotated for E8
sourcepoints2 = specsource(8,sourcepointorigin2,sourcethet2)


#source point and vector!
sourcep2, sv2 = FS(100,sourcepoints2, sourcethet2,origin8)

#Reflection off of E8
points8, vects8 = RSEPCN(coeffellipse56,sourcep2,sv2, xrange, ellipseorigin,ellipsethetaxyz, 'pos')

# %%
#Reflection off E3 from E8
#transform angle is thet6
sourcethetflat = [0,0,0]

#retransforming without changing angle at all
sp38, v38 = RT(points8,vects8,thet6,origin8, sourcethetflat,origin3)

points38, vects38 = RSEPCN(coeffellipse, sp38,v38,xrange,ellipseorigin,ellipsethetaxyz, 'neg')
#none?

# %%
#reflection off E2 from E3
sp23, v23 = RT(points38,vects38,sourcethetflat,origin3, sourcethetflat,origin2)

points23, vects23 = RSEPCN(coeffellipse, sp23,v23,xrange,ellipseorigin,ellipsethetaxyz, 'pos')

# %%
#reflection off E6 from E2
sp62, v62 = RT(points23,vects23,sourcethetflat,origin2, thet6,origin6)

points62, vects62 = RSEPCN(coeffellipse, sp62,v62,xrange,ellipseorigin,ellipsethetaxyz, 'neg')

# %%
pl3dsurf = pl.figure().gca(projection = '3d')
#ellipse 1
pl3dsurf.plot_trisurf(X1i,Y1i,Z1i, linewidth = .2, antialiased=True, color = 'mediumseagreen',alpha=0.7) #GLOBAL
pl3dsurf.plot_trisurf(X2i,Y2i,Z2i, linewidth = .2, antialiased=True, color = 'mediumseagreen',alpha=0.7) #GLOBAL

#ellipse3
pl3dsurf.plot_trisurf(X1n,Y1n,Z1n, linewidth = .2, antialiased=True, color = 'mediumturquoise',alpha=0.7) #GLOBAL
pl3dsurf.plot_trisurf(X2n,Y2n,Z2n, linewidth = .2, antialiased=True, color = 'mediumturquoise',alpha=0.7) #GLOBAL

#ellipse 2
pl3dsurf.plot_trisurf(X3i,Y3i,Z3i, linewidth = .2, antialiased=True, color = 'c',alpha=0.7) #GLOBAL
pl3dsurf.plot_trisurf(X4i,Y4i,Z4i, linewidth = .2, antialiased=True, color = 'c',alpha=0.7) #GLOBAL

#ellipse 4
pl3dsurf.plot_trisurf(X3n,Y3n,Z3n, linewidth = .2, antialiased=True, color = 'dodgerblue',alpha=0.7) #GLOBAL
pl3dsurf.plot_trisurf(X4n,Y4n,Z4n, linewidth = .2, antialiased=True, color = 'dodgerblue',alpha=0.7) #GLOBAL

#ellipse5
pl3dsurf.plot_trisurf(X5,Y5,Z5, linewidth = .2, antialiased=True, color = 'indigo',alpha=0.7) #GLOBAL
pl3dsurf.plot_trisurf(X6,Y6,Z6, linewidth = .2, antialiased=True, color = 'indigo',alpha=0.7) #GLOBAL

#ellipse6
pl3dsurf.plot_trisurf(X5n,Y5n,Z5n, linewidth = .2, antialiased=True, color = 'orchid',alpha=0.7) #GLOBAL
pl3dsurf.plot_trisurf(X6n,Y6n,Z6n, linewidth = .2, antialiased=True, color = 'orchid',alpha=0.7) #GLOBAL

#ellipse 7
pl3dsurf.plot_trisurf(X7,Y7,Z7,linewidth = .2, antialiased=True, color = 'magenta',alpha=0.7)

#ellipse8
pl3dsurf.plot_trisurf(X9,Y9,Z9, linewidth = .2, antialiased=True, color = 'skyblue',alpha=0.7) #GLOBAL
pl3dsurf.plot_trisurf(X10,Y10,Z10, linewidth = .2, antialiased=True, color = 'skyblue',alpha=0.7) #GLOBAL

#ellipse9
pl3dsurf.plot_trisurf(X9n,Y9n,Z9n, linewidth = .2, antialiased=True, color = 'forestgreen',alpha=0.7) #GLOBAL
pl3dsurf.plot_trisurf(X10n,Y10n,Z10n, linewidth = .2, antialiased=True, color = 'forestgreen',alpha=0.7) #GLOBAL

#ellipse10
pl3dsurf.plot_trisurf(X11,Y11,Z11,linewidth = .2, antialiased=True, color = 'pink',alpha=0.7)

#well I'm messing up somewhere


points1T, vects1T = RT(points1, vects1,thet,origin1,ellipsethetaxyz,ellipseorigin)

for i in range (0,len(vects1T)):
    x,y,z = ML(points1T[i], vects1T[i], 100)
    pl3dsurf.plot(x,y,z, color = 'red')
#for i in range (0,len(vects41)):
    #x,y,z = ML(points41T[i], vects41[i], 200)
    #pl3dsurf.plot(x,y,z, color = 'orange')
#for i in range (0,len(vects54)):
    #x,y,z = ML(points54T[i], vects54T[i], 200)
    #pl3dsurf.plot(x,y,z, color = 'yellow')

pl.show()

# %%
pl3dsurf = pl.figure().gca(projection = '3d')
#ellipse 1
pl3dsurf.plot_trisurf(X1i,Y1i,Z1i, linewidth = .2, antialiased=True, color = 'mediumseagreen',alpha=0.7) #GLOBAL
pl3dsurf.plot_trisurf(X2i,Y2i,Z2i, linewidth = .2, antialiased=True, color = 'mediumseagreen',alpha=0.7) #GLOBAL

#ellipse3
pl3dsurf.plot_trisurf(X1n,Y1n,Z1n, linewidth = .2, antialiased=True, color = 'mediumturquoise',alpha=0.7) #GLOBAL
pl3dsurf.plot_trisurf(X2n,Y2n,Z2n, linewidth = .2, antialiased=True, color = 'mediumturquoise',alpha=0.7) #GLOBAL

#ellipse 2
pl3dsurf.plot_trisurf(X3i,Y3i,Z3i, linewidth = .2, antialiased=True, color = 'c',alpha=0.7) #GLOBAL
pl3dsurf.plot_trisurf(X4i,Y4i,Z4i, linewidth = .2, antialiased=True, color = 'c',alpha=0.7) #GLOBAL

#ellipse 4
pl3dsurf.plot_trisurf(X3n,Y3n,Z3n, linewidth = .2, antialiased=True, color = 'dodgerblue',alpha=0.7) #GLOBAL
pl3dsurf.plot_trisurf(X4n,Y4n,Z4n, linewidth = .2, antialiased=True, color = 'dodgerblue',alpha=0.7) #GLOBAL

#ellipse5
pl3dsurf.plot_trisurf(X5,Y5,Z5, linewidth = .2, antialiased=True, color = 'indigo',alpha=0.7) #GLOBAL
pl3dsurf.plot_trisurf(X6,Y6,Z6, linewidth = .2, antialiased=True, color = 'indigo',alpha=0.7) #GLOBAL

#ellipse6
pl3dsurf.plot_trisurf(X5n,Y5n,Z5n, linewidth = .2, antialiased=True, color = 'orchid',alpha=0.7) #GLOBAL
pl3dsurf.plot_trisurf(X6n,Y6n,Z6n, linewidth = .2, antialiased=True, color = 'orchid',alpha=0.7) #GLOBAL

#ellipse 7
pl3dsurf.plot_trisurf(X7,Y7,Z7,linewidth = .2, antialiased=True, color = 'magenta',alpha=0.7)

#ellipse8
pl3dsurf.plot_trisurf(X9,Y9,Z9, linewidth = .2, antialiased=True, color = 'skyblue',alpha=0.7) #GLOBAL
pl3dsurf.plot_trisurf(X10,Y10,Z10, linewidth = .2, antialiased=True, color = 'skyblue',alpha=0.7) #GLOBAL

#ellipse9
pl3dsurf.plot_trisurf(X9n,Y9n,Z9n, linewidth = .2, antialiased=True, color = 'forestgreen',alpha=0.7) #GLOBAL
pl3dsurf.plot_trisurf(X10n,Y10n,Z10n, linewidth = .2, antialiased=True, color = 'forestgreen',alpha=0.7) #GLOBAL    
points2T = transformP(points8,origin8)
vects2T = transformV(vects8,thet6)
points38T = transformP(points38,origin3)
points23T = transformP(points23,origin2)
#points62T = transformP(points62,origin6)
#vects62T = transformV(vects62,thet6)

for i in range (0,len(points2T)):
    x,y,z = ML(points2T[i], vects2T[i], 200)
    pl3dsurf.plot(x,y,z, color = 'blue')
for i in range (0,len(points38T)):
    x,y,z = ML(points38T[i], vects38[i], 200)
    pl3dsurf.plot(x,y,z, color = 'green')
for i in range (0,len(points23T)):
    x,y,z = ML(points23T[i], vects23[i], 200)
    pl3dsurf.plot(x,y,z, color = 'purple')
#for i in range (0,len(points62T)):
    #x,y,z = ML(points62T[i], vects62T[i], 200)
    #pl3dsurf.plot(x,y,z, color = 'purple')
pl.show()

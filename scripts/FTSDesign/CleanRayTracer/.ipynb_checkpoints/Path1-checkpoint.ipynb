# %% [markdown]
# This should follow path 1 as seen on page 138. This should be E10 to E8 to E3 to E2 to E 6 to E7.
#
# CHANGE EQUATIONS OF E7 AND E10 ON PATH 1 AND ON PATH 2

# %%
import numpy as np
import matplotlib.pyplot as pl
import itertools
from mpl_toolkits.mplot3d import Axes3D
from RayTraceFunCleaner import *
from random import uniform
import random

# %%
#GLOBAL ORIGINS (MAKING THE CORRECT FTS)
originG = [0,0,0] #literally the global origin
originG = [0,0,0] # the global origin
thetG = [0,0,0] # rotation with respect to itself aka 0,0,0
origin1 = [-32.075,-128,0] #x,y (ellipse1)
origin2 = [64.15-32.075,-128,0] #x,y (ellipse2)
origin3 = [-32.075,128,0] #x,y (ellipse3)
origin4 = [64.15-32.075,128,0] #x,y  (ellipse4)
origin5 = [128.3-32.075,-120.501,0] # for 3d
#origin5 = [128.3-32.075,-128,0] #for 2d
origin6 = [128.3-32.075,120.501,0] # for 3d
#origin6 = [128.3-32.075,128,0] for 2d
origin7 = [160.375-32.075,-7.5,40]
origin8 = [-64.15-32.075,-120.501,0] #for 3d
origin9 = [-64.15-32.075,120.501,0] #for 3d
#origin8 = [-64.15-32.075,-128,0] for 2d
#origin9 = [-64.15-32.075,128,0] for 2d
origin10 = [-96.225-32.075,7.5,-40]

originpolar1 = [-128.3,0.0,0.0]
originpolar2 = [-64.15,0.0,0.0]
originpolar3 = [64.15,0.0,0.0]
originpolar4 = [128.3,0.0,0.0]

thet = [0,0,0] #A
thet5 = [0,0,-.116385] #testing
thet6 = [0,0,.116385] #testing
thet7 = [0,0.309319724356,1.31064594453]
thet10 = [0,0.309319724356,-1.31064594453] #negative of thet7?


#added digits for accuracy
coeffellipse7 = [164.54585247700001,99.690818975602866,130.9086635] #for ellipse 7
coeffellipse56 = [256.65344272795591,248.39387505453516,64.58693753]  #for ellipses 5&6&8&9
coeffellipse = [263.915180503,256.0,64.15] #for center ellipses

#center ellipses
X1,Y1,Z1,X2,Y2,Z2 = FTSEC(50,np.pi/8, coeffellipse, 64.15, 'pos')
X1n,Y1n,Z1n,X2n,Y2n,Z2n = FTSEC(50,np.pi/8, coeffellipse, 64.15, 'neg')

Xset1, Yset1, Zset1 = SR2(32.07, X1,Y1,Z1, originG)
Xset2, Yset2, Zset2 = SR2(32.07, X2, Y2, Z2, originG)
Xset1n, Yset1n, Zset1n = SR2(32.07, X1n,Y1n,Z1n, originG)
Xset2n, Yset2n, Zset2n = SR2(32.07, X2n, Y2n, Z2n, originG)


#ellipse 1
X1i,Y1i,Z1i = transformLG(Xset1,Yset1,Zset1,origin1,thet)
X2i,Y2i,Z2i = transformLG(Xset2,Yset2,Zset2,origin1,thet)

#ellipse 3
X1n,Y1n,Z1n = transformLG(Xset1n,Yset1n,Zset1n,origin3,thet)
X2n,Y2n,Z2n = transformLG(Xset2n,Yset2n,Zset2n,origin3,thet)

#ellipse 2
X3i,Y3i,Z3i = transformLG(Xset1,Yset1,Zset1,origin2,thet)
X4i,Y4i,Z4i = transformLG(Xset2,Yset2,Zset2,origin2,thet)

#ellipse 4
X3n,Y3n,Z3n = transformLG(Xset1n,Yset1n,Zset1n,origin4,thet)
X4n,Y4n,Z4n = transformLG(Xset2n,Yset2n,Zset2n,origin4,thet)

#Side ellipses

#ellipse 5&6
X5,Y5,Z5,X6,Y6,Z6 = FTSEC(50,np.pi/8, coeffellipse56, 350, 'pos')
X5n,Y5n,Z5n,X6n,Y6n,Z6n = FTSEC(50,np.pi/8, coeffellipse56, 350, 'neg')

#ellipse5
Xset5, Yset5, Zset5= transformLG(X5,Y5,Z5,origin5,thet5)
Xset6, Yset6, Zset6 = transformLG(X6,Y6,Z6,origin5,thet5)

X5,Y5,Z5 = SR2(32.07, Xset5,Yset5,Zset5, origin5)
X6,Y6,Z6 = SR2(32.07, Xset6, Yset6, Zset6, origin5)

#ellipse6
Xset5n,Yset5n,Zset5n = transformLG(X5n,Y5n,Z5n,origin6,thet6)
Xset6n,Yset6n,Zset6n = transformLG(X6n,Y6n,Z6n,origin6,thet6)

X5n,Y5n,Z5n = SR2(32.07,Xset5n,Yset5n,Zset5n,origin6)
X6n,Y6n,Z6n = SR2(32.07,Xset6n,Yset6n,Zset6n,origin6)

#ellipse 7 
X7,Y7,Z7,X8,Y8,Z8 = FTSEC(50,np.pi*.99, coeffellipse7, 306, 'pos')
X7n,Y7n,Z7n,X8n,Y8n,Z8n = FTSEC(50,np.pi*.99, coeffellipse7, 306, 'neg')

Xset7,Yset7,Zset7 = transformLG(X7,Y7,Z7,origin7,thet7)
Xset8,Yset8,Zset8 = transformLG(X8,Y8,Z8,origin7,thet7)

X7,Y7,Z7 = SR2(32.07,Xset7, Yset7, Zset7, origin7)
X8,Y8,Z8 = SR2(32.07,Xset8, Yset8, Zset8, origin7)

#ellipse 8&9
X9i,Y9i,Z9i,X10i,Y10i,Z10i = FTSEC(50,np.pi/8, coeffellipse56, 150, 'pos')
X9n,Y9n,Z9n,X10n,Y10n,Z10n = FTSEC(50,np.pi/8, coeffellipse56, 150, 'neg')

#ellipse 8
Xset9,Yset9,Zset9 = transformLG(X9i,Y9i,Z9i,origin8,thet6)
Xset10,Yset10,Zset10 = transformLG(X10i,Y10i,Z10i,origin8,thet6)

X9,Y9,Z9 = SR2(32.07, Xset9,Yset9,Zset9, origin8)
X10,Y10,Z10 = SR2(32.07, Xset10, Yset10, Zset10, origin8)

#ellipse 9
Xset9n,Yset9n,Zset9n = transformLG(X9n,Y9n,Z9n,origin9,thet5)
Xset10n,Yset10n,Zset10n = transformLG(X10n,Y10n,Z10n,origin9,thet5)

X9n,Y9n,Z9n = SR2(32.07, Xset9n,Yset9n,Zset9n, origin9)
X10n,Y10n,Z10n = SR2(32.07, Xset10n, Yset10n, Zset10n, origin9)

#ellipse 10
X11i,Y11i,Z11i,X12i,Y12i,Z12i = FTSEC(50,np.pi*2, coeffellipse7, 329.29, 'pos') #LOCAL
Xset11,Yset11,Zset11 = transformLG(X11i,Y11i,Z11i,origin10,thet10) #GLOBAL
Xset12,Yset12,Zset12 = transformLG(X12i,Y12i,Z12i,origin10,thet10) #GLOBAL
Ecenter = [-128.3,0,0]
X11,Y11,Z11 = SR10(32.07, Xset11,Yset11,Zset11, Ecenter) #SELECTED GLOBAL
X12,Y12,Z12 = SR10(32.07, Xset12,Yset12,Zset12, Ecenter) #SELECTED GLOBAL
# Out:
# /Users/Lab/software/scripts/FTSDesign/CleanRayTracer/RayTraceFunCleaner.py:224: RuntimeWarning: invalid value encountered in sqrt
#   yc1 = np.sqrt((1-(((xc)**2)/(coeffellipse[0]**2)))*coeffellipse[1]**2) #pos side of ellipse
# /Users/Lab/software/scripts/FTSDesign/CleanRayTracer/RayTraceFunCleaner.py:225: RuntimeWarning: invalid value encountered in sqrt
#   yc2 = -np.sqrt((1-(((xc)**2)/(coeffellipse[0]**2)))*coeffellipse[1]**2) #neg side of ellipse

# %%
center10,range10, = xrangeGL(X11,Y11,Z11,X12,Y12,Z12,origin10,thet10)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-2584801140d0> in <module>()
# ----> 1 center10,range10, = xrangeGL(X11,Y11,Z11,X12,Y12,Z12,origin10,thet10)
#
# NameError: name 'xrangeGL' is not defined

# %%
pl3dsurf = pl.figure().gca(projection = '3d')
#ellipse 8
pl3dsurf.plot_trisurf(X9i,Y9i,Z9i, linewidth = .2, antialiased=True, color = 'mediumseagreen',alpha=0.7) #LOCAL
pl3dsurf.plot_trisurf(X10i,Y10i,Z10i, linewidth = .2, antialiased=True, color = 'mediumseagreen',alpha=0.7) #LOCAL

pl3dsurf.plot_trisurf(Xset9,Yset9,Zset9, linewidth = .2, antialiased=True, color = 'skyblue',alpha=0.7) #GLOBAL
pl3dsurf.plot_trisurf(Xset10,Yset10,Zset10, linewidth = .2, antialiased=True, color = 'skyblue',alpha=0.7) #GLOBAL

pl3dsurf.plot_trisurf(X9,Y9,Z9, linewidth = .2, antialiased=True, color = 'black') #GLOBAL
pl3dsurf.plot_trisurf(X10,Y10,Z10, linewidth = .2, antialiased=True, color = 'black') #GLOBAL

X9f,Y9f,Z9f = transformGL(X9,Y9,Z9,origin8,thet6)
X10f,Y10f,Z10f = transformGL(X10,Y10,Z10,origin8,thet6)

pl3dsurf.plot_trisurf(X9f,Y9f,Z9f, linewidth = .2, antialiased=True, color = 'black') #LOCAL
pl3dsurf.plot_trisurf(X10f,Y10f,Z10f, linewidth = .2, antialiased=True, color = 'black') #LOCAL

pl.show()

# %% [markdown]
# pl3dsurf = pl.figure().gca(projection = '3d')
# #ellipse 1
# pl3dsurf.plot_trisurf(X1i,Y1i,Z1i, linewidth = .2, antialiased=True, color = 'mediumseagreen',alpha=0.7) #GLOBAL
# pl3dsurf.plot_trisurf(X2i,Y2i,Z2i, linewidth = .2, antialiased=True, color = 'mediumseagreen',alpha=0.7) #GLOBAL
# #ellipse8
# pl3dsurf.plot_trisurf(X9,Y9,Z9, linewidth = .2, antialiased=True, color = 'skyblue',alpha=0.7) #GLOBAL
# pl3dsurf.plot_trisurf(X10,Y10,Z10, linewidth = .2, antialiased=True, color = 'skyblue',alpha=0.7) #GLOBAL
# pl.show()

# %%
xcenter8,xrange8 = xrangeGL6(X9,Y9,Z9,origin8,thet6)
xcenter8
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-171a928dbf7f> in <module>()
# ----> 1 xcenter8,xrange8 = xrangeGL6(X9,Y9,Z9,origin8,thet6)
#       2 xcenter8
#
# NameError: name 'xrangeGL6' is not defined

# %%
pl3dsurf = pl.figure().gca(projection = '3d')
#ellipse 8 (globally)
pl3dsurf.plot_trisurf(X9,Y9,Z9, linewidth = .2, antialiased=True, color = 'skyblue',alpha=0.7) #GLOBAL
pl3dsurf.plot_trisurf(X10,Y10,Z10, linewidth = .2, antialiased=True, color = 'skyblue',alpha=0.7) #GLOBAL

pl3dsurf.plot_trisurf(X9f,Y9f,Z9f, linewidth = .2, antialiased=True, color = 'skyblue',alpha=0.7) #LOCAL
pl3dsurf.plot_trisurf(X10f,Y10f,Z10f, linewidth = .2, antialiased=True, color = 'skyblue',alpha=0.7) #LOCAL

#pl3dsurf.scatter([xcenter8[0]],[xcenter8[1]],0)
pl.show()

# %%
print(min((min(Z9f),min(Z10f))))
print(max((max(Z9f),max(Z10f))))
# Out:
# -31.6301474977
# 31.6301474977

# %%
#source 1 being reflected off of E8

originL = [0,0,0] #locally (or the global origin)
thetL = [0,0,0]

#creating the source (around the focus of E8) LOCALLY 
sourcepointorigin = [-64.585,0,0] #locally 
sourcethet = [np.pi/2,0,.2593] #locally
sourcepoints = specsource(8,sourcepointorigin,sourcethet) #local


#source point and vector!
sourcep1, sv1 = FS(1500,sourcepoints, sourcethet,origin8) #local
#Reflection off of E8
points8, vects8 = RSEPCN(coeffellipse56,sourcep1,sv1, xrange8, xcenter8,thetL, 'pos') #local
# above is local

#CHANGE XRANGE TO BE THE RANGE DETERMINED BY GLOBAL RESTRICTION

# %%
#show it all locally then
pl3dsurf = pl.figure().gca(projection = '3d')
#ellipse 8 (globally)
pl3dsurf.plot_trisurf(X9,Y9,Z9, linewidth = .2, antialiased=True, color = 'skyblue',alpha=0.7) #GLOBAL
pl3dsurf.plot_trisurf(X10,Y10,Z10, linewidth = .2, antialiased=True, color = 'skyblue',alpha=0.7) #GLOBAL
p8,v8 = RT(points8,vects8,thet6,origin8,thet,originG) #global
for i in range (0,len(points8)):
    x,y,z = ML(p8[i], v8[i], 200) #global
    pl3dsurf.plot(x,y,z, color = 'yellow')

#WHY STILL SLIGHTLY SHIFTED GODDAMNIT

#OKAY SO IT'S WORKING LOCALLY. THEREFORE IT IS THE RETRANSFORMATION THAT IS OFF. 
#OR IT IS THAT XRANGE HAS TO BE IMPLEMENTED IN DRAWING! DUH IDIOT. 
#CLEARLY the drawing and the mathematical representation are off. 
#so see email to steve about what to do now. (which way to to choose x range) 
#right now xrange is applied locally in one case and globally in the other, which is not correct
#wait ok now it seems to be working as one would expect, apply it?
pl.show()

# %%
#reflection off of E3 from E8
sp8,v8 = RT(points8,vects8,thet6,origin8,thet,origin3)
points38,vects38 = RSEPCN(coeffellipse,sp8,v8,32.07,originL,thetL,'neg')

# %%
pl3dsurf = pl.figure().gca(projection = '3d')
#ellipse3
pl3dsurf.plot_trisurf(X1n,Y1n,Z1n, linewidth = .2, antialiased=True, color = 'mediumturquoise',alpha=0.7) #GLOBAL
pl3dsurf.plot_trisurf(X2n,Y2n,Z2n, linewidth = .2, antialiased=True, color = 'mediumturquoise',alpha=0.7) #GLOBAL

p38,v38 = RT(points38,vects38,thet,origin3,thet,originG)
for i in range (0,len(p38)):
    x,y,z = ML(p38[i], v38[i], 200)
    pl3dsurf.plot(x,y,z, color = 'yellow')
pl.show()

# %%
#reflection off of E2 from E3
sp3,v3 = RT(points38,vects38,thet,origin3,thet,origin2)
points23,vects23 = RSEPCN(coeffellipse,sp3,v3,32.07,originL,thetL,'pos')

# %%
pl3dsurf = pl.figure().gca(projection = '3d')
#ellipse 2
pl3dsurf.plot_trisurf(X3i,Y3i,Z3i, linewidth = .2, antialiased=True, color = 'c',alpha=0.7) #GLOBAL
pl3dsurf.plot_trisurf(X4i,Y4i,Z4i, linewidth = .2, antialiased=True, color = 'c',alpha=0.7) #GLOBAL

p23,v23 = RT(points23,vects23,thet,origin2,thet,originG)
for i in range (0,len(p23)):
    x,y,z = ML(p23[i], v23[i], 200)
    pl3dsurf.plot(x,y,z, color = 'yellow')
pl.show()

# %%
#reflection off of E6 from E2
xcenter6,xrange6 = xrangeGL(X5n,Y5n,Z5n,origin6,thet6)
sp2,v2 = RT(points23,vects23,thet,origin2,thet6,origin6)
points62,vects62 = RSEPCN(coeffellipse,sp2,v2,xrange6,xcenter6,thetL,'neg')

# %%
pl3dsurf = pl.figure().gca(projection = '3d')
#ellipse6
pl3dsurf.plot_trisurf(X5n,Y5n,Z5n, linewidth = .2, antialiased=True, color = 'orchid',alpha=0.7) #GLOBAL
pl3dsurf.plot_trisurf(X6n,Y6n,Z6n, linewidth = .2, antialiased=True, color = 'orchid',alpha=0.7) #GLOBAL

p62,v62 = RT(points62,vects62,thet6,origin6,thet,originG)
for i in range (0,len(p62)):
    x,y,z = ML(p62[i], v62[i], 200)
    pl3dsurf.plot(x,y,z, color = 'yellow')
pl.show()

# %%
pl3dsurf = pl.figure().gca(projection = '3d')
#ellipse 1
pl3dsurf.plot_trisurf(X1i,Y1i,Z1i, linewidth = .2, antialiased=True, color = 'mediumseagreen',alpha=0.7) #GLOBAL
pl3dsurf.plot_trisurf(X2i,Y2i,Z2i, linewidth = .2, antialiased=True, color = 'mediumseagreen',alpha=0.7) #GLOBAL

#ellipse3
pl3dsurf.plot_trisurf(X1n,Y1n,Z1n, linewidth = .2, antialiased=True, color = 'mediumturquoise',alpha=0.7) #GLOBAL
pl3dsurf.plot_trisurf(X2n,Y2n,Z2n, linewidth = .2, antialiased=True, color = 'mediumturquoise',alpha=0.7) #GLOBAL

#ellipse 2
pl3dsurf.plot_trisurf(X3i,Y3i,Z3i, linewidth = .2, antialiased=True, color = 'c',alpha=0.7) #GLOBAL
pl3dsurf.plot_trisurf(X4i,Y4i,Z4i, linewidth = .2, antialiased=True, color = 'c',alpha=0.7) #GLOBAL

#ellipse 4
pl3dsurf.plot_trisurf(X3n,Y3n,Z3n, linewidth = .2, antialiased=True, color = 'dodgerblue',alpha=0.7) #GLOBAL
pl3dsurf.plot_trisurf(X4n,Y4n,Z4n, linewidth = .2, antialiased=True, color = 'dodgerblue',alpha=0.7) #GLOBAL

#ellipse5
pl3dsurf.plot_trisurf(X5,Y5,Z5, linewidth = .2, antialiased=True, color = 'indigo',alpha=0.7) #GLOBAL
pl3dsurf.plot_trisurf(X6,Y6,Z6, linewidth = .2, antialiased=True, color = 'indigo',alpha=0.7) #GLOBAL

#ellipse6
pl3dsurf.plot_trisurf(X5n,Y5n,Z5n, linewidth = .2, antialiased=True, color = 'orchid',alpha=0.7) #GLOBAL
pl3dsurf.plot_trisurf(X6n,Y6n,Z6n, linewidth = .2, antialiased=True, color = 'orchid',alpha=0.7) #GLOBAL

#ellipse 7
#pl3dsurf.plot_trisurf(X7,Y7,Z7,linewidth = .2, antialiased=True, color = 'magenta',alpha=0.7)

#ellipse8
pl3dsurf.plot_trisurf(X9,Y9,Z9, linewidth = .2, antialiased=True, color = 'skyblue',alpha=0.7) #GLOBAL
pl3dsurf.plot_trisurf(X10,Y10,Z10, linewidth = .2, antialiased=True, color = 'skyblue',alpha=0.7) #GLOBAL

#ellipse9
pl3dsurf.plot_trisurf(X9n,Y9n,Z9n, linewidth = .2, antialiased=True, color = 'forestgreen',alpha=0.7) #GLOBAL
pl3dsurf.plot_trisurf(X10n,Y10n,Z10n, linewidth = .2, antialiased=True, color = 'forestgreen',alpha=0.7) #GLOBAL

#ellipse10
#pl3dsurf.plot_trisurf(X11,Y11,Z11,linewidth = .2, antialiased=True, color = 'pink',alpha=0.7)

for i in range (0,len(points8)):
    x,y,z = ML(p8[i], v8[i], 250)
    pl3dsurf.plot(x,y,z, color = 'red')

for i in range (0,len(p38)):
    x,y,z = ML(p38[i], v38[i], 250)
    pl3dsurf.plot(x,y,z, color = 'orange')

for i in range (0,len(p23)):
    x,y,z = ML(p23[i], v23[i], 250)
    pl3dsurf.plot(x,y,z, color = 'yellow')

for i in range (0,len(p62)):
    x,y,z = ML(p62[i], v62[i], 250)
    pl3dsurf.plot(x,y,z, color = 'green')
    
#change to make the length not 250 but based on intersection points
pl.title('Path1')   
pl.show()

# %%
f, (ax1, ax2) = pl.subplots(1, 2, sharey=False)

p8,v8 = RT(points8,vects8,thet6,origin8,thet,originG)
for i in range (0,len(p8)):
    ax1.scatter(p8[i][0],p8[i][2], marker = 'o', color = 'blue')
    ax1.autoscale(True)
ax1.set_title('E8')
ax1.set_xlabel('X axis')
ax1.set_ylabel('Z axis')

p23,v23 = RT(points23,vects23,thet,origin2,thet,originG)
for i in range (0,len(p23)):
    ax2.scatter(p23[i][0],-p23[i][2], marker = 'o', color = 'blue')
    ax2.autoscale(True)
ax2.set_title('E2')
ax2.set_xlabel('X axis')
ax2.set_ylabel('Z axis')

pl.tight_layout()
pl.show()

#seems to be rotated/flipped appropriately
#FORCE x and y axes to be the same scale (squares)

# %%
f, (ax1, ax2) = pl.subplots(1, 2, sharey=False)
p38,v38 = RT(points38,vects38,thet,origin3,thet,originG)
for i in range (0,len(p38)):
    ax1.scatter(p38[i][0],p38[i][2], marker = 'o', color = 'red')
    ax1.autoscale(True)
ax1.set_title('E3')
ax1.set_xlabel('X axis')
ax1.set_ylabel('Z axis')

p62,v62 = RT(points62,vects62,thet6,origin6,thet,originG)
for i in range (0,len(p62)):
    ax2.scatter(p62[i][0],-p62[i][2], marker = 'o', color = 'red')
    ax2.autoscale(True)
ax2.set_title('E6')
ax2.set_xlabel('X axis')
ax2.set_ylabel('Z axis')

pl.tight_layout()
pl.show()

#some similaries but not obvious?

# %% [markdown]
# This is merely a notebook to create the ellipsoids on the other side of the FTS. It should essentially be the same simply rotated by $\pi$ around the x-axis.
#
# It is also a beginning of working on rotating the ellipse symmetrically about the x-y plane.
#
# Mira

# %%
import numpy as np
import matplotlib.pyplot as pl
import itertools
from mpl_toolkits.mplot3d import Axes3D
from RayTraceFun import *

# %%
#rotates a given ellipse around the x axis
def rotatestrand(theta, coeffellipse):
    Rotated = []
    xc,yc1,yc2,zc = createellipse(coeffellipse)
    for i in range (0,100): 
        v = [xc[i], yc1[i],zc[i]] # number of original points
        v2 = np.array(np.dot(v,Rx(theta))) #multiplied by rotation vector
        Rotated.append(v2[0]) #rotated vectors
    xcR1 = []
    ycR1 = []
    zcR1 = []
    for j in range (0,100):
        xcR1.append(Rotated[j][0])
        ycR1.append(Rotated[j][1])
        zcR1.append(Rotated[j][2])
    return xcR1,ycR1,zcR1
#FIRST MAKING SURE THAT THE ELLIPSOID ROTATION IS 
#SYMMETRICAL ABOUT THE X-Y PLANE
def createzsym(a,n, coeffellipse): #a: number of divisions, n: total angle
    x = []
    y = []
    z = []
    for i in range (0,a):
        theta = np.linspace(-n/2, n/2, a)
        x2,y2,z2 = rotatestrand(theta[i], coeffellipse)
        x.extend(x2)
        y.extend(y2)
        z.extend(z2)
    return x,y,z
#this should work??

#'negative' ellipse
def createzneg(a,n, coeffellipse):
    x1 = []
    y1 = []
    z1 = []
    for i in range (0,a):
        theta = np.linspace(0,n,a)
        x,y,z = rotatestrand(np.pi + theta[i], coeffellipse)
        x1.extend(x)
        y1.extend(y)
        z1.extend(z)
    return x1,y1,z1

# %%
pl3dsurf = pl.figure().gca(projection = '3d')
X,Y,Z = createz(50,np.pi/4, [263.9,256,64.15])
X.pop(0)
Y.pop(0)
Z.pop(0)
#pl3dsurf.plot(X,Y,Z, marker = 'o', markersize = 2)
pl3dsurf.plot_trisurf(X,Y,Z, linewidth = .2, antialiased=True)
#pl3dsurf.set_zlim(-4,0)
x,y1,y2,z = createellipse([263.9,256,64.15])
pl3dsurf.plot(x,y1,z, color = 'white')
pl.show()

# %%
#how this is rotated around the x axis by pi/2
pl3d = pl.figure().gca(projection = '3d')
x,y,y2,z = createellipse([263.9,256,64.15])
pl3d.plot(x,y,z, 'blue')

x1,y1,z1 = rotatestrand(np.pi/2,[263.9,256,64.15] )
pl.plot(x1,y1,z1 ,'green')

x2,y2,z2 = rotatestrand(-np.pi/2,[263.9,256,64.15] )
pl.plot(x2,y2,z2 ,'red')

x3,y3,z3 = rotatestrand(np.pi,[263.9,256,64.15] )
pl.plot(x3,y3,z3 ,'orange')

x4,y4,z4 = rotatestrand(-np.pi/4,[263.9,256,64.15] )
pl.plot(x4,y4,z4 ,'purple')

pl.show()

# %%
#how createzsym should be working
pl3d = pl.figure().gca(projection = '3d')
for i in range (0,50):
    n = np.pi/2
    theta = np.linspace(-n/2, n/2, 50)
    x2,y2,z2 = rotatestrand(theta[i], [263.9,256,64.15])
    pl3d.plot(x2,y2,z2 ,'red')
pl.show()

# %%
pl3dsurf = pl.figure().gca(projection = '3d')
X,Y,Z = createzneg(50,np.pi/2, [263.9,256,64.15])
#X.pop(0)
#Y.pop(0)
#Z.pop(0)
#pl3dsurf.plot(X,Y,Z, marker = 'o', markersize = 2)
pl3dsurf.plot_trisurf(X,Y,Z, linewidth = .2, antialiased=True)
#pl3dsurf.set_zlim(-4,0)
x,y1,y2,z = createellipse([263.9,256,64.15])
pl3dsurf.plot(x,y1,z, color = 'white')
pl.show()

# %%
#how createzsymneg should be working
pl3d = pl.figure().gca(projection = '3d')
for i in range (0,50):
    n = np.pi/2
    theta = np.linspace(-n/2, n/2, 50)
    x2,y2,z2 = rotatestrand(np.pi+theta[i], [263.9,256,64.15])
    pl3d.plot(x2,y2,z2 ,'red')
pl.show()

# %%
#why is it not triangulating correctly
pl3dsurf = pl.figure().gca(projection = '3d')
X,Y,Z = createzsym(50,np.pi/2, [263.9,256,64.15])
#pl3dsurf.plot(X,Y,Z, marker = 'o', markersize = 2)
pl3dsurf.plot_trisurf(X,Y,Z, linewidth = .05, antialiased=True)
#pl3dsurf.set_zlim(-4,0)
x,y1,y2,z = createellipse([263.9,256,64.15])
pl3dsurf.plot(x,y1,z, color = 'white')
pl.show()

# %% [markdown]
# Given up on making the unbounded ellipse work, it seems to be a basic problem with triangulation program rather than anythnig in the code generating the points.
#
# From here using the bounded functions

# %%
coeffellipse = [263.9,256,64.15]
#plot two to have it be symmetric about the x-axis
X,Y,Z = createzbounded(50,np.pi/8, coeffellipse, 64.15)
X1,Y1,Z1 = createzbounded(50,-np.pi/8, coeffellipse, 64.15)

origin1 = [90,0]
X2,Y2,Z2 = createzboundshift(50,np.pi/8, coeffellipse, 64.15, origin1)
X3,Y3,Z3 = createzboundshift(50,-np.pi/8, coeffellipse, 64.15, origin1)


pl3dsurf = pl.figure().gca(projection = '3d')
pl3dsurf.plot_trisurf(X,Y,Z, linewidth = .2, antialiased=True)
pl3dsurf.plot_trisurf(X1,Y1,Z1, linewidth = .2, antialiased=True)
pl3dsurf.plot_trisurf(X2,Y2,Z2, linewidth = .2, antialiased=True)
pl3dsurf.plot_trisurf(X3,Y3,Z3, linewidth = .2, antialiased=True)
pl3dsurf.set_ylim([0,300])
pl.show()



#JUST plot two?

# %% [markdown]
# When the 'reverse' ellipsoids are added, their foci must be at the CENTER of the opposite ellipsoids. therefore they cannot simply be rotated around the x axis, they must also be shifted in the x-axis to align the foci and ellipsoids.
